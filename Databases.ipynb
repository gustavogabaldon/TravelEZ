# %% [markdown]
# This is the code that is looking at looking at our datasets, and allowing us to analyze the datasets that we are working with. In this project, we are primarly working with three types of datasets: housing prices, food costs, and overall living expenses. For the housing prices dataset, we are looking at three specific cities: Moscow, Melbourne, and Utrech. The other two types of datasets are singular datasets. For analyzing the datasets, I will be using pandas and numpy to analyze the prices for the various datasets, and I will be creating python dictionaries, the equivalent of c++ maps to store this data in a data structure.

# %% [markdown]
# Now, we will be looking at the analysis of the Moscow Housing Data Set, creating a python dictionary (c++ map equivalent) from this dataset.

# %%
# import pandas
import pandas as pd
# Read CSV
moscow_df = pd.read_csv('moscow_data.csv')
moscow_data = moscow_df[['Region', 'Price', 'Number of rooms']]
# Convert the Data from the CSV to a Dictionary
moscow_dict = {}
for index, row in moscow_data.iterrows():
    # General Entry into the Dictionary
    region = row['Region']
    price = row['Price']
    num_rooms = row['Number of rooms']

    # Seeing if a region (key) is already in the dictionary or not, appending if is, making new key if not)
    if region not in moscow_dict:
        moscow_dict[region] = []
    moscow_dict[region].append((price, num_rooms))

# Sorting the dictionary by price and printing the top 5 most and least expensive apartments
for region in moscow_dict:
    moscow_sorted = sorted(moscow_dict[region], key=lambda x: x[0], reverse=True)
    most_expensive = moscow_sorted[:5]
    least_expensive = moscow_sorted[-5:]

    # Printing sorted list
    print(f"Region: {region} (rubles)")
    print("Most Expensive Apartments:")
    for apt in most_expensive:
        print(f"Price: {apt[0]}, Number of Rooms: {apt[1]+1.0}")
    print("Least Expensive Apartments:")
    for apart in least_expensive:
        print(f"Price: {apart[0]}, Number of Rooms: {apart[1]+1.0}")
    print("\n")
# Out:
# Region: Moscow region (rubles)
# Most Expensive Apartments:
# Price: 53000000.0, Number of Rooms: 3.0
# Price: 51500000.0, Number of Rooms: 3.0
# Price: 49500000.0, Number of Rooms: 3.0
# Price: 24398774.0, Number of Rooms: 4.0
# Price: 24340000.0, Number of Rooms: 5.0
# Least Expensive Apartments:
# Price: 1941650.0, Number of Rooms: 1.0
# Price: 1939125.0, Number of Rooms: 1.0
# Price: 1939125.0, Number of Rooms: 1.0
# Price: 1939125.0, Number of Rooms: 1.0
# Price: 1939125.0, Number of Rooms: 1.0
#
#
# Region: Moscow (rubles)
# Most Expensive Apartments:
# Price: 2455020000.0, Number of Rooms: 7.0
# Price: 1732170825.0, Number of Rooms: 1.0
# Price: 1517997000.0, Number of Rooms: 7.0
# Price: 1475430000.0, Number of Rooms: 6.0
# Price: 1422120000.0, Number of Rooms: 6.0
# Least Expensive Apartments:
# Price: 2390000.0, Number of Rooms: 1.0
# Price: 1750000.0, Number of Rooms: 1.0
# Price: 1560000.0, Number of Rooms: 1.0
# Price: 1420000.0, Number of Rooms: 1.0
# Price: 1150000.0, Number of Rooms: 1.0

# %% [markdown]
# Next, we will be looking at the analysis of the Melbourne Housing Data Set, creating a python dictionary (c++ map equivalent) from this dataset.

# %%
# import pandas
import pandas as pd
# Read CSV
melb_df = pd.read_csv('melb_data.csv')
melb_data = melb_df[['Suburb', 'Price', 'Rooms']]
# Convert the Data from the CSV to a Dictionary
melb_dict = {}
for index, row in melb_data.iterrows():
  # General Entry into the Dictionary
  suburb = row['Suburb']
  price = row['Price']
  num_rooms = row['Rooms']

  # Seeing if a suburb (key) is already in the dictionary or not, appending if is, making new key if not)
  if suburb not in melb_dict:
    melb_dict[suburb] = []
  melb_dict[suburb].append((price, num_rooms))

# Sorting the dictionary by price and printing the top 5 most and least expensive apartments
for region in melb_dict:
  melb_sorted = sorted(melb_dict[region], key=lambda x: x[0], reverse=True)
  most_expensive = melb_sorted[:5]
  least_expensive = melb_sorted[-5:]

  # Printing sorted list
  print(f"Region: {region} (AUDs)")
  print("Most Expensive Apartments:")
  for apt in most_expensive:
    print(f"Price: {apt[0]}, Number of Rooms: {apt[1]+1.0}")
  print("Least Expensive Apartments:")
  for apart in least_expensive:
    print(f"Price: {apart[0]}, Number of Rooms: {apart[1]+1.0}")
  print("\n")
# Out:
# Region: Abbotsford (AUDs)
# Most Expensive Apartments:
# Price: 1876000.0, Number of Rooms: 4.0
# Price: 1636000.0, Number of Rooms: 3.0
# Price: 1635000.0, Number of Rooms: 4.0
# Price: 1600000.0, Number of Rooms: 5.0
# Price: 1542000.0, Number of Rooms: 5.0
# Least Expensive Apartments:
# Price: 470000.0, Number of Rooms: 2.0
# Price: 457000.0, Number of Rooms: 2.0
# Price: 441000.0, Number of Rooms: 2.0
# Price: 426000.0, Number of Rooms: 2.0
# Price: 300000.0, Number of Rooms: 2.0
#
#
# Region: Airport West (AUDs)
# Most Expensive Apartments:
# Price: 1250000.0, Number of Rooms: 4.0
# Price: 1064000.0, Number of Rooms: 4.0
# Price: 1042000.0, Number of Rooms: 4.0
# Price: 1026000.0, Number of Rooms: 5.0
# Price: 1000001.0, Number of Rooms: 4.0
# Least Expensive Apartments:
# Price: 480000.0, Number of Rooms: 3.0
# Price: 462500.0, Number of Rooms: 3.0
# Price: 454000.0, Number of Rooms: 3.0
# Price: 450000.0, Number of Rooms: 3.0
# Price: 440000.0, Number of Rooms: 3.0
#
#
# Region: Albert Park (AUDs)
# Most Expensive Apartments:
# Price: 4735000.0, Number of Rooms: 5.0
# Price: 3755000.0, Number of Rooms: 4.0
# Price: 3560000.0, Number of Rooms: 5.0
# Price: 3010000.0, Number of Rooms: 4.0
# Price: 2950000.0, Number of Rooms: 5.0
# Least Expensive Apartments:
# Price: 985000.0, Number of Rooms: 2.0
# Price: 980000.0, Number of Rooms: 3.0
# Price: 685000.0, Number of Rooms: 3.0
# Price: 647000.0, Number of Rooms: 3.0
# Price: 442500.0, Number of Rooms: 2.0
#
#
# Region: Alphington (AUDs)
# Most Expensive Apartments:
# Price: 2840000.0, Number of Rooms: 6.0
# Price: 2750000.0, Number of Rooms: 5.0
# Price: 2345000.0, Number of Rooms: 5.0
# Price: 2220000.0, Number of Rooms: 5.0
# Price: 2100000.0, Number of Rooms: 5.0
# Least Expensive Apartments:
# Price: 465000.0, Number of Rooms: 3.0
# Price: 390000.0, Number of Rooms: 3.0
# Price: 330000.0, Number of Rooms: 2.0
# Price: 320000.0, Number of Rooms: 2.0
# Price: 316000.0, Number of Rooms: 2.0
#
#
# Region: Altona (AUDs)
# Most Expensive Apartments:
# Price: 1780000.0, Number of Rooms: 5.0
# Price: 1525000.0, Number of Rooms: 6.0
# Price: 1500000.0, Number of Rooms: 4.0
# Price: 1480000.0, Number of Rooms: 6.0
# Price: 1360000.0, Number of Rooms: 5.0
# Least Expensive Apartments:
# Price: 447000.0, Number of Rooms: 3.0
# Price: 440000.0, Number of Rooms: 3.0
# Price: 425000.0, Number of Rooms: 3.0
# Price: 406000.0, Number of Rooms: 3.0
# Price: 391000.0, Number of Rooms: 3.0
#
#
# Region: Altona North (AUDs)
# Most Expensive Apartments:
# Price: 1500000.0, Number of Rooms: 6.0
# Price: 1405000.0, Number of Rooms: 4.0
# Price: 1200000.0, Number of Rooms: 5.0
# Price: 1085000.0, Number of Rooms: 6.0
# Price: 1070000.0, Number of Rooms: 4.0
# Least Expensive Apartments:
# Price: 585000.0, Number of Rooms: 4.0
# Price: 510000.0, Number of Rooms: 3.0
# Price: 451500.0, Number of Rooms: 4.0
# Price: 421000.0, Number of Rooms: 3.0
# Price: 292000.0, Number of Rooms: 3.0
#
#
# Region: Armadale (AUDs)
# Most Expensive Apartments:
# Price: 5525000.0, Number of Rooms: 7.0
# Price: 5200000.0, Number of Rooms: 6.0
# Price: 5100000.0, Number of Rooms: 5.0
# Price: 4200000.0, Number of Rooms: 5.0
# Price: 4060000.0, Number of Rooms: 5.0
# Least Expensive Apartments:
# Price: 390000.0, Number of Rooms: 2.0
# Price: 380000.0, Number of Rooms: 2.0
# Price: 324000.0, Number of Rooms: 2.0
# Price: 315000.0, Number of Rooms: 2.0
# Price: 280000.0, Number of Rooms: 2.0
#
#
# Region: Ascot Vale (AUDs)
# Most Expensive Apartments:
# Price: 2425000.0, Number of Rooms: 7.0
# Price: 2250000.0, Number of Rooms: 7.0
# Price: 2100000.0, Number of Rooms: 6.0
# Price: 1905000.0, Number of Rooms: 6.0
# Price: 1850000.0, Number of Rooms: 5.0
# Least Expensive Apartments:
# Price: 440000.0, Number of Rooms: 3.0
# Price: 432000.0, Number of Rooms: 3.0
# Price: 425500.0, Number of Rooms: 3.0
# Price: 390000.0, Number of Rooms: 2.0
# Price: 390000.0, Number of Rooms: 3.0
#
#
# Region: Ashburton (AUDs)
# Most Expensive Apartments:
# Price: 3510000.0, Number of Rooms: 6.0
# Price: 2950000.0, Number of Rooms: 9.0
# Price: 2752000.0, Number of Rooms: 6.0
# Price: 2650000.0, Number of Rooms: 5.0
# Price: 2550000.0, Number of Rooms: 4.0
# Least Expensive Apartments:
# Price: 968000.0, Number of Rooms: 4.0
# Price: 955000.0, Number of Rooms: 4.0
# Price: 925000.0, Number of Rooms: 3.0
# Price: 900000.0, Number of Rooms: 4.0
# Price: 500000.0, Number of Rooms: 3.0
#
#
# Region: Ashwood (AUDs)
# Most Expensive Apartments:
# Price: 1680000.0, Number of Rooms: 5.0
# Price: 1650000.0, Number of Rooms: 4.0
# Price: 1631000.0, Number of Rooms: 4.0
# Price: 1575000.0, Number of Rooms: 4.0
# Price: 1540000.0, Number of Rooms: 5.0
# Least Expensive Apartments:
# Price: 700000.0, Number of Rooms: 3.0
# Price: 700000.0, Number of Rooms: 3.0
# Price: 690000.0, Number of Rooms: 3.0
# Price: 600000.0, Number of Rooms: 3.0
# Price: 535000.0, Number of Rooms: 3.0
#
#
# Region: Avondale Heights (AUDs)
# Most Expensive Apartments:
# Price: 1600000.0, Number of Rooms: 5.0
# Price: 1600000.0, Number of Rooms: 5.0
# Price: 1300000.0, Number of Rooms: 5.0
# Price: 1250000.0, Number of Rooms: 6.0
# Price: 1200000.0, Number of Rooms: 5.0
# Least Expensive Apartments:
# Price: 522500.0, Number of Rooms: 3.0
# Price: 500000.0, Number of Rooms: 4.0
# Price: 470000.0, Number of Rooms: 3.0
# Price: 440000.0, Number of Rooms: 3.0
# Price: 411000.0, Number of Rooms: 3.0
#
#
# Region: Balaclava (AUDs)
# Most Expensive Apartments:
# Price: 1819000.0, Number of Rooms: 5.0
# Price: 1690000.0, Number of Rooms: 4.0
# Price: 1680000.0, Number of Rooms: 4.0
# Price: 1475000.0, Number of Rooms: 4.0
# Price: 1193000.0, Number of Rooms: 4.0
# Least Expensive Apartments:
# Price: 416000.0, Number of Rooms: 3.0
# Price: 410000.0, Number of Rooms: 3.0
# Price: 328500.0, Number of Rooms: 2.0
# Price: 290000.0, Number of Rooms: 2.0
# Price: 280000.0, Number of Rooms: 2.0
#
#
# Region: Balwyn (AUDs)
# Most Expensive Apartments:
# Price: 4000000.0, Number of Rooms: 7.0
# Price: 4000000.0, Number of Rooms: 6.0
# Price: 3900000.0, Number of Rooms: 6.0
# Price: 3812000.0, Number of Rooms: 6.0
# Price: 3600000.0, Number of Rooms: 6.0
# Least Expensive Apartments:
# Price: 526000.0, Number of Rooms: 3.0
# Price: 500000.0, Number of Rooms: 3.0
# Price: 460000.0, Number of Rooms: 3.0
# Price: 460000.0, Number of Rooms: 3.0
# Price: 390000.0, Number of Rooms: 2.0
#
#
# Region: Balwyn North (AUDs)
# Most Expensive Apartments:
# Price: 4000000.0, Number of Rooms: 6.0
# Price: 3690000.0, Number of Rooms: 6.0
# Price: 3360000.0, Number of Rooms: 5.0
# Price: 3300000.0, Number of Rooms: 6.0
# Price: 3250000.0, Number of Rooms: 6.0
# Least Expensive Apartments:
# Price: 700000.0, Number of Rooms: 4.0
# Price: 691500.0, Number of Rooms: 3.0
# Price: 685000.0, Number of Rooms: 3.0
# Price: 682000.0, Number of Rooms: 3.0
# Price: 560000.0, Number of Rooms: 3.0
#
#
# Region: Bentleigh (AUDs)
# Most Expensive Apartments:
# Price: 2700000.0, Number of Rooms: 5.0
# Price: 2700000.0, Number of Rooms: 5.0
# Price: 2620000.0, Number of Rooms: 5.0
# Price: 2520000.0, Number of Rooms: 5.0
# Price: 2435000.0, Number of Rooms: 5.0
# Least Expensive Apartments:
# Price: 420000.0, Number of Rooms: 3.0
# Price: 410000.0, Number of Rooms: 3.0
# Price: 405000.0, Number of Rooms: 3.0
# Price: 380000.0, Number of Rooms: 3.0
# Price: 360000.0, Number of Rooms: 3.0
#
#
# Region: Bentleigh East (AUDs)
# Most Expensive Apartments:
# Price: 1962000.0, Number of Rooms: 3.0
# Price: 1960000.0, Number of Rooms: 5.0
# Price: 1860000.0, Number of Rooms: 5.0
# Price: 1815000.0, Number of Rooms: 5.0
# Price: 1800000.0, Number of Rooms: 6.0
# Least Expensive Apartments:
# Price: 485000.0, Number of Rooms: 3.0
# Price: 380000.0, Number of Rooms: 3.0
# Price: 380000.0, Number of Rooms: 2.0
# Price: 370000.0, Number of Rooms: 2.0
# Price: 340000.0, Number of Rooms: 3.0
#
#
# Region: Box Hill (AUDs)
# Most Expensive Apartments:
# Price: 4000000.0, Number of Rooms: 4.0
# Price: 2831000.0, Number of Rooms: 4.0
# Price: 2770000.0, Number of Rooms: 5.0
# Price: 2285000.0, Number of Rooms: 6.0
# Price: 2150500.0, Number of Rooms: 7.0
# Least Expensive Apartments:
# Price: 465000.0, Number of Rooms: 3.0
# Price: 420000.0, Number of Rooms: 3.0
# Price: 400000.0, Number of Rooms: 3.0
# Price: 340000.0, Number of Rooms: 2.0
# Price: 288000.0, Number of Rooms: 2.0
#
#
# Region: Braybrook (AUDs)
# Most Expensive Apartments:
# Price: 1000000.0, Number of Rooms: 5.0
# Price: 925000.0, Number of Rooms: 4.0
# Price: 882000.0, Number of Rooms: 5.0
# Price: 870000.0, Number of Rooms: 4.0
# Price: 868000.0, Number of Rooms: 3.0
# Least Expensive Apartments:
# Price: 502000.0, Number of Rooms: 4.0
# Price: 495000.0, Number of Rooms: 4.0
# Price: 495000.0, Number of Rooms: 4.0
# Price: 475000.0, Number of Rooms: 3.0
# Price: 441700.0, Number of Rooms: 4.0
#
#
# Region: Brighton (AUDs)
# Most Expensive Apartments:
# Price: 5800000.0, Number of Rooms: 6.0
# Price: 5500000.0, Number of Rooms: 6.0
# Price: 4700000.0, Number of Rooms: 6.0
# Price: 4250000.0, Number of Rooms: 5.0
# Price: 4225000.0, Number of Rooms: 5.0
# Least Expensive Apartments:
# Price: 502000.0, Number of Rooms: 3.0
# Price: 495000.0, Number of Rooms: 2.0
# Price: 380000.0, Number of Rooms: 2.0
# Price: 375000.0, Number of Rooms: 2.0
# Price: 290000.0, Number of Rooms: 2.0
#
#
# Region: Brighton East (AUDs)
# Most Expensive Apartments:
# Price: 3207000.0, Number of Rooms: 6.0
# Price: 2900000.0, Number of Rooms: 6.0
# Price: 2840000.0, Number of Rooms: 5.0
# Price: 2820000.0, Number of Rooms: 5.0
# Price: 2750000.0, Number of Rooms: 6.0
# Least Expensive Apartments:
# Price: 681000.0, Number of Rooms: 2.0
# Price: 620000.0, Number of Rooms: 3.0
# Price: 585000.0, Number of Rooms: 3.0
# Price: 563000.0, Number of Rooms: 3.0
# Price: 340000.0, Number of Rooms: 2.0
#
#
# Region: Brunswick (AUDs)
# Most Expensive Apartments:
# Price: 2545000.0, Number of Rooms: 6.0
# Price: 2500000.0, Number of Rooms: 6.0
# Price: 2230000.0, Number of Rooms: 5.0
# Price: 1925000.0, Number of Rooms: 4.0
# Price: 1900000.0, Number of Rooms: 5.0
# Least Expensive Apartments:
# Price: 315000.0, Number of Rooms: 2.0
# Price: 279500.0, Number of Rooms: 2.0
# Price: 272500.0, Number of Rooms: 2.0
# Price: 240000.0, Number of Rooms: 2.0
# Price: 170000.0, Number of Rooms: 2.0
#
#
# Region: Brunswick West (AUDs)
# Most Expensive Apartments:
# Price: 2350000.0, Number of Rooms: 4.0
# Price: 1700000.0, Number of Rooms: 5.0
# Price: 1585000.0, Number of Rooms: 5.0
# Price: 1500000.0, Number of Rooms: 5.0
# Price: 1445000.0, Number of Rooms: 4.0
# Least Expensive Apartments:
# Price: 285000.0, Number of Rooms: 2.0
# Price: 275000.0, Number of Rooms: 2.0
# Price: 265000.0, Number of Rooms: 2.0
# Price: 263100.0, Number of Rooms: 2.0
# Price: 252000.0, Number of Rooms: 2.0
#
#
# Region: Bulleen (AUDs)
# Most Expensive Apartments:
# Price: 1751000.0, Number of Rooms: 5.0
# Price: 1730000.0, Number of Rooms: 6.0
# Price: 1580000.0, Number of Rooms: 5.0
# Price: 1540000.0, Number of Rooms: 5.0
# Price: 1505000.0, Number of Rooms: 5.0
# Least Expensive Apartments:
# Price: 812500.0, Number of Rooms: 4.0
# Price: 794000.0, Number of Rooms: 4.0
# Price: 787000.0, Number of Rooms: 4.0
# Price: 760000.0, Number of Rooms: 6.0
# Price: 599900.0, Number of Rooms: 3.0
#
#
# Region: Burwood (AUDs)
# Most Expensive Apartments:
# Price: 2150000.0, Number of Rooms: 6.0
# Price: 2068000.0, Number of Rooms: 4.0
# Price: 2000000.0, Number of Rooms: 5.0
# Price: 1890000.0, Number of Rooms: 5.0
# Price: 1815000.0, Number of Rooms: 3.0
# Least Expensive Apartments:
# Price: 633000.0, Number of Rooms: 3.0
# Price: 625000.0, Number of Rooms: 4.0
# Price: 605000.0, Number of Rooms: 3.0
# Price: 580000.0, Number of Rooms: 3.0
# Price: 570000.0, Number of Rooms: 4.0
#
#
# Region: Camberwell (AUDs)
# Most Expensive Apartments:
# Price: 5020000.0, Number of Rooms: 5.0
# Price: 4760000.0, Number of Rooms: 5.0
# Price: 4060000.0, Number of Rooms: 5.0
# Price: 3550000.0, Number of Rooms: 5.0
# Price: 3400000.0, Number of Rooms: 4.0
# Least Expensive Apartments:
# Price: 530000.0, Number of Rooms: 3.0
# Price: 502000.0, Number of Rooms: 3.0
# Price: 435000.0, Number of Rooms: 3.0
# Price: 435000.0, Number of Rooms: 3.0
# Price: 430000.0, Number of Rooms: 3.0
#
#
# Region: Canterbury (AUDs)
# Most Expensive Apartments:
# Price: 8000000.0, Number of Rooms: 6.0
# Price: 4750000.0, Number of Rooms: 5.0
# Price: 4350000.0, Number of Rooms: 5.0
# Price: 3800000.0, Number of Rooms: 5.0
# Price: 3725000.0, Number of Rooms: 4.0
# Least Expensive Apartments:
# Price: 736000.0, Number of Rooms: 3.0
# Price: 722000.0, Number of Rooms: 3.0
# Price: 690500.0, Number of Rooms: 3.0
# Price: 685000.0, Number of Rooms: 3.0
# Price: 645000.0, Number of Rooms: 3.0
#
#
# Region: Carlton North (AUDs)
# Most Expensive Apartments:
# Price: 3450000.0, Number of Rooms: 5.0
# Price: 2950000.0, Number of Rooms: 4.0
# Price: 2718000.0, Number of Rooms: 5.0
# Price: 2520000.0, Number of Rooms: 5.0
# Price: 2450000.0, Number of Rooms: 6.0
# Least Expensive Apartments:
# Price: 570000.0, Number of Rooms: 3.0
# Price: 520000.0, Number of Rooms: 3.0
# Price: 468000.0, Number of Rooms: 2.0
# Price: 437000.0, Number of Rooms: 2.0
# Price: 390000.0, Number of Rooms: 2.0
#
#
# Region: Carnegie (AUDs)
# Most Expensive Apartments:
# Price: 1966000.0, Number of Rooms: 5.0
# Price: 1910000.0, Number of Rooms: 4.0
# Price: 1900000.0, Number of Rooms: 6.0
# Price: 1880000.0, Number of Rooms: 5.0
# Price: 1840000.0, Number of Rooms: 4.0
# Least Expensive Apartments:
# Price: 285000.0, Number of Rooms: 2.0
# Price: 270000.0, Number of Rooms: 2.0
# Price: 260000.0, Number of Rooms: 2.0
# Price: 255000.0, Number of Rooms: 2.0
# Price: 250000.0, Number of Rooms: 2.0
#
#
# Region: Caulfield (AUDs)
# Most Expensive Apartments:
# Price: 1665000.0, Number of Rooms: 6.0
# Price: 1600000.0, Number of Rooms: 5.0
# Price: 1090000.0, Number of Rooms: 4.0
# Price: 1070000.0, Number of Rooms: 3.0
# Price: 722500.0, Number of Rooms: 3.0
# Least Expensive Apartments:
# Price: 570000.0, Number of Rooms: 3.0
# Price: 550000.0, Number of Rooms: 3.0
# Price: 535000.0, Number of Rooms: 3.0
# Price: 323000.0, Number of Rooms: 2.0
# Price: 131000.0, Number of Rooms: 5.0
#
#
# Region: Caulfield North (AUDs)
# Most Expensive Apartments:
# Price: 2830000.0, Number of Rooms: 5.0
# Price: 2625000.0, Number of Rooms: 5.0
# Price: 2170000.0, Number of Rooms: 5.0
# Price: 2005000.0, Number of Rooms: 4.0
# Price: 1925000.0, Number of Rooms: 5.0
# Least Expensive Apartments:
# Price: 420000.0, Number of Rooms: 3.0
# Price: 361000.0, Number of Rooms: 2.0
# Price: 350000.0, Number of Rooms: 2.0
# Price: 305000.0, Number of Rooms: 2.0
# Price: 290000.0, Number of Rooms: 2.0
#
#
# Region: Caulfield South (AUDs)
# Most Expensive Apartments:
# Price: 2450000.0, Number of Rooms: 6.0
# Price: 1960000.0, Number of Rooms: 5.0
# Price: 1916000.0, Number of Rooms: 5.0
# Price: 1774500.0, Number of Rooms: 5.0
# Price: 1700000.0, Number of Rooms: 5.0
# Least Expensive Apartments:
# Price: 500000.0, Number of Rooms: 3.0
# Price: 490000.0, Number of Rooms: 3.0
# Price: 295000.0, Number of Rooms: 2.0
# Price: 290000.0, Number of Rooms: 2.0
# Price: 275500.0, Number of Rooms: 2.0
#
#
# Region: Chadstone (AUDs)
# Most Expensive Apartments:
# Price: 1507000.0, Number of Rooms: 5.0
# Price: 1460000.0, Number of Rooms: 4.0
# Price: 1415500.0, Number of Rooms: 5.0
# Price: 1310000.0, Number of Rooms: 6.0
# Price: 1301000.0, Number of Rooms: 4.0
# Least Expensive Apartments:
# Price: 701000.0, Number of Rooms: 4.0
# Price: 700000.0, Number of Rooms: 4.0
# Price: 674000.0, Number of Rooms: 3.0
# Price: 650000.0, Number of Rooms: 4.0
# Price: 510000.0, Number of Rooms: 3.0
#
#
# Region: Clifton Hill (AUDs)
# Most Expensive Apartments:
# Price: 3010000.0, Number of Rooms: 5.0
# Price: 1825000.0, Number of Rooms: 5.0
# Price: 1680000.0, Number of Rooms: 4.0
# Price: 1662500.0, Number of Rooms: 5.0
# Price: 1660000.0, Number of Rooms: 4.0
# Least Expensive Apartments:
# Price: 556000.0, Number of Rooms: 3.0
# Price: 533000.0, Number of Rooms: 3.0
# Price: 495000.0, Number of Rooms: 3.0
# Price: 465000.0, Number of Rooms: 2.0
# Price: 325000.0, Number of Rooms: 2.0
#
#
# Region: Coburg (AUDs)
# Most Expensive Apartments:
# Price: 2250000.0, Number of Rooms: 9.0
# Price: 1900000.0, Number of Rooms: 7.0
# Price: 1790000.0, Number of Rooms: 6.0
# Price: 1742000.0, Number of Rooms: 5.0
# Price: 1615000.0, Number of Rooms: 6.0
# Least Expensive Apartments:
# Price: 434000.0, Number of Rooms: 3.0
# Price: 430000.0, Number of Rooms: 2.0
# Price: 425000.0, Number of Rooms: 3.0
# Price: 241000.0, Number of Rooms: 2.0
# Price: 145000.0, Number of Rooms: 5.0
#
#
# Region: Coburg North (AUDs)
# Most Expensive Apartments:
# Price: 2000000.0, Number of Rooms: 4.0
# Price: 1240000.0, Number of Rooms: 5.0
# Price: 1172000.0, Number of Rooms: 6.0
# Price: 1050000.0, Number of Rooms: 5.0
# Price: 1011000.0, Number of Rooms: 5.0
# Least Expensive Apartments:
# Price: 570000.0, Number of Rooms: 3.0
# Price: 532500.0, Number of Rooms: 3.0
# Price: 530000.0, Number of Rooms: 3.0
# Price: 525000.0, Number of Rooms: 3.0
# Price: 330000.0, Number of Rooms: 3.0
#
#
# Region: Collingwood (AUDs)
# Most Expensive Apartments:
# Price: 1645000.0, Number of Rooms: 3.0
# Price: 1500000.0, Number of Rooms: 4.0
# Price: 1470000.0, Number of Rooms: 4.0
# Price: 1470000.0, Number of Rooms: 4.0
# Price: 1430000.0, Number of Rooms: 3.0
# Least Expensive Apartments:
# Price: 415000.0, Number of Rooms: 2.0
# Price: 372000.0, Number of Rooms: 2.0
# Price: 366000.0, Number of Rooms: 2.0
# Price: 365000.0, Number of Rooms: 2.0
# Price: 365000.0, Number of Rooms: 2.0
#
#
# Region: Doncaster (AUDs)
# Most Expensive Apartments:
# Price: 2600000.0, Number of Rooms: 5.0
# Price: 2168000.0, Number of Rooms: 6.0
# Price: 2000000.0, Number of Rooms: 5.0
# Price: 1955000.0, Number of Rooms: 5.0
# Price: 1924500.0, Number of Rooms: 5.0
# Least Expensive Apartments:
# Price: 655000.0, Number of Rooms: 4.0
# Price: 522500.0, Number of Rooms: 3.0
# Price: 492500.0, Number of Rooms: 3.0
# Price: 452000.0, Number of Rooms: 3.0
# Price: 400000.0, Number of Rooms: 3.0
#
#
# Region: Eaglemont (AUDs)
# Most Expensive Apartments:
# Price: 3300000.0, Number of Rooms: 5.0
# Price: 2850000.0, Number of Rooms: 3.0
# Price: 2710000.0, Number of Rooms: 6.0
# Price: 2600000.0, Number of Rooms: 5.0
# Price: 2550000.0, Number of Rooms: 5.0
# Least Expensive Apartments:
# Price: 1190000.0, Number of Rooms: 4.0
# Price: 1100000.0, Number of Rooms: 4.0
# Price: 750000.0, Number of Rooms: 3.0
# Price: 600000.0, Number of Rooms: 3.0
# Price: 525000.0, Number of Rooms: 3.0
#
#
# Region: Elsternwick (AUDs)
# Most Expensive Apartments:
# Price: 3000000.0, Number of Rooms: 5.0
# Price: 2806000.0, Number of Rooms: 5.0
# Price: 2600000.0, Number of Rooms: 5.0
# Price: 2600000.0, Number of Rooms: 5.0
# Price: 2410000.0, Number of Rooms: 5.0
# Least Expensive Apartments:
# Price: 550000.0, Number of Rooms: 3.0
# Price: 537000.0, Number of Rooms: 3.0
# Price: 500000.0, Number of Rooms: 3.0
# Price: 410000.0, Number of Rooms: 3.0
# Price: 385000.0, Number of Rooms: 2.0
#
#
# Region: Elwood (AUDs)
# Most Expensive Apartments:
# Price: 3572000.0, Number of Rooms: 4.0
# Price: 3175000.0, Number of Rooms: 5.0
# Price: 2400000.0, Number of Rooms: 5.0
# Price: 2275000.0, Number of Rooms: 6.0
# Price: 2200000.0, Number of Rooms: 5.0
# Least Expensive Apartments:
# Price: 347000.0, Number of Rooms: 2.0
# Price: 340000.0, Number of Rooms: 2.0
# Price: 326000.0, Number of Rooms: 2.0
# Price: 313000.0, Number of Rooms: 2.0
# Price: 300000.0, Number of Rooms: 2.0
#
#
# Region: Essendon (AUDs)
# Most Expensive Apartments:
# Price: 2800000.0, Number of Rooms: 6.0
# Price: 2620000.0, Number of Rooms: 7.0
# Price: 2390000.0, Number of Rooms: 4.0
# Price: 2355000.0, Number of Rooms: 5.0
# Price: 2335000.0, Number of Rooms: 6.0
# Least Expensive Apartments:
# Price: 310000.0, Number of Rooms: 2.0
# Price: 291000.0, Number of Rooms: 2.0
# Price: 280000.0, Number of Rooms: 2.0
# Price: 280000.0, Number of Rooms: 2.0
# Price: 250000.0, Number of Rooms: 2.0
#
#
# Region: Essendon North (AUDs)
# Most Expensive Apartments:
# Price: 1605000.0, Number of Rooms: 5.0
# Price: 1580000.0, Number of Rooms: 4.0
# Price: 1535000.0, Number of Rooms: 4.0
# Price: 1425000.0, Number of Rooms: 4.0
# Price: 1360000.0, Number of Rooms: 6.0
# Least Expensive Apartments:
# Price: 415500.0, Number of Rooms: 3.0
# Price: 396000.0, Number of Rooms: 3.0
# Price: 393000.0, Number of Rooms: 3.0
# Price: 340000.0, Number of Rooms: 3.0
# Price: 260000.0, Number of Rooms: 2.0
#
#
# Region: Fairfield (AUDs)
# Most Expensive Apartments:
# Price: 2350000.0, Number of Rooms: 4.0
# Price: 2000000.0, Number of Rooms: 5.0
# Price: 1800000.0, Number of Rooms: 4.0
# Price: 1730000.0, Number of Rooms: 5.0
# Price: 1700000.0, Number of Rooms: 4.0
# Least Expensive Apartments:
# Price: 505000.0, Number of Rooms: 3.0
# Price: 445000.0, Number of Rooms: 3.0
# Price: 438000.0, Number of Rooms: 3.0
# Price: 400000.0, Number of Rooms: 3.0
# Price: 300000.0, Number of Rooms: 2.0
#
#
# Region: Fitzroy (AUDs)
# Most Expensive Apartments:
# Price: 4011000.0, Number of Rooms: 5.0
# Price: 3310000.0, Number of Rooms: 5.0
# Price: 3200000.0, Number of Rooms: 5.0
# Price: 2725000.0, Number of Rooms: 4.0
# Price: 2700000.0, Number of Rooms: 4.0
# Least Expensive Apartments:
# Price: 490000.0, Number of Rooms: 2.0
# Price: 465000.0, Number of Rooms: 2.0
# Price: 458000.0, Number of Rooms: 2.0
# Price: 456000.0, Number of Rooms: 2.0
# Price: 420000.0, Number of Rooms: 2.0
#
#
# Region: Fitzroy North (AUDs)
# Most Expensive Apartments:
# Price: 3400000.0, Number of Rooms: 5.0
# Price: 2875000.0, Number of Rooms: 6.0
# Price: 2555000.0, Number of Rooms: 4.0
# Price: 2300000.0, Number of Rooms: 4.0
# Price: 2300000.0, Number of Rooms: 5.0
# Least Expensive Apartments:
# Price: 490000.0, Number of Rooms: 3.0
# Price: 381000.0, Number of Rooms: 2.0
# Price: 358500.0, Number of Rooms: 2.0
# Price: 330000.0, Number of Rooms: 2.0
# Price: 330000.0, Number of Rooms: 2.0
#
#
# Region: Flemington (AUDs)
# Most Expensive Apartments:
# Price: 2268000.0, Number of Rooms: 5.0
# Price: 1700000.0, Number of Rooms: 5.0
# Price: 1550000.0, Number of Rooms: 6.0
# Price: 1500000.0, Number of Rooms: 4.0
# Price: 1340000.0, Number of Rooms: 5.0
# Least Expensive Apartments:
# Price: 360000.0, Number of Rooms: 3.0
# Price: 350000.0, Number of Rooms: 3.0
# Price: 345000.0, Number of Rooms: 2.0
# Price: 280000.0, Number of Rooms: 2.0
# Price: 250000.0, Number of Rooms: 2.0
#
#
# Region: Footscray (AUDs)
# Most Expensive Apartments:
# Price: 1450000.0, Number of Rooms: 5.0
# Price: 1375000.0, Number of Rooms: 4.0
# Price: 1362000.0, Number of Rooms: 4.0
# Price: 1320000.0, Number of Rooms: 4.0
# Price: 1320000.0, Number of Rooms: 4.0
# Least Expensive Apartments:
# Price: 227000.0, Number of Rooms: 2.0
# Price: 216000.0, Number of Rooms: 2.0
# Price: 210000.0, Number of Rooms: 2.0
# Price: 170000.0, Number of Rooms: 2.0
# Price: 85000.0, Number of Rooms: 2.0
#
#
# Region: Glen Iris (AUDs)
# Most Expensive Apartments:
# Price: 3860000.0, Number of Rooms: 6.0
# Price: 3730000.0, Number of Rooms: 6.0
# Price: 3500000.0, Number of Rooms: 5.0
# Price: 3400000.0, Number of Rooms: 5.0
# Price: 3400000.0, Number of Rooms: 6.0
# Least Expensive Apartments:
# Price: 330000.0, Number of Rooms: 2.0
# Price: 328000.0, Number of Rooms: 2.0
# Price: 320000.0, Number of Rooms: 2.0
# Price: 291000.0, Number of Rooms: 2.0
# Price: 260000.0, Number of Rooms: 2.0
#
#
# Region: Glenroy (AUDs)
# Most Expensive Apartments:
# Price: 1220000.0, Number of Rooms: 3.0
# Price: 1217500.0, Number of Rooms: 5.0
# Price: 1158000.0, Number of Rooms: 4.0
# Price: 1150000.0, Number of Rooms: 6.0
# Price: 1100000.0, Number of Rooms: 5.0
# Least Expensive Apartments:
# Price: 340000.0, Number of Rooms: 3.0
# Price: 320500.0, Number of Rooms: 3.0
# Price: 270000.0, Number of Rooms: 3.0
# Price: 250000.0, Number of Rooms: 3.0
# Price: 230000.0, Number of Rooms: 3.0
#
#
# Region: Gowanbrae (AUDs)
# Most Expensive Apartments:
# Price: 990000.0, Number of Rooms: 5.0
# Price: 970000.0, Number of Rooms: 5.0
# Price: 945000.0, Number of Rooms: 5.0
# Price: 931000.0, Number of Rooms: 5.0
# Price: 900000.0, Number of Rooms: 4.0
# Least Expensive Apartments:
# Price: 504000.0, Number of Rooms: 4.0
# Price: 500000.0, Number of Rooms: 4.0
# Price: 485000.0, Number of Rooms: 4.0
# Price: 468000.0, Number of Rooms: 4.0
# Price: 390000.0, Number of Rooms: 4.0
#
#
# Region: Hadfield (AUDs)
# Most Expensive Apartments:
# Price: 1102000.0, Number of Rooms: 4.0
# Price: 918000.0, Number of Rooms: 5.0
# Price: 880000.0, Number of Rooms: 5.0
# Price: 870000.0, Number of Rooms: 5.0
# Price: 870000.0, Number of Rooms: 4.0
# Least Expensive Apartments:
# Price: 487000.0, Number of Rooms: 3.0
# Price: 468000.0, Number of Rooms: 3.0
# Price: 465000.0, Number of Rooms: 4.0
# Price: 460000.0, Number of Rooms: 3.0
# Price: 330000.0, Number of Rooms: 3.0
#
#
# Region: Hampton (AUDs)
# Most Expensive Apartments:
# Price: 3470000.0, Number of Rooms: 6.0
# Price: 3325000.0, Number of Rooms: 5.0
# Price: 3250000.0, Number of Rooms: 5.0
# Price: 3201000.0, Number of Rooms: 6.0
# Price: 3200000.0, Number of Rooms: 5.0
# Least Expensive Apartments:
# Price: 587000.0, Number of Rooms: 3.0
# Price: 580000.0, Number of Rooms: 2.0
# Price: 500000.0, Number of Rooms: 2.0
# Price: 500000.0, Number of Rooms: 3.0
# Price: 450000.0, Number of Rooms: 3.0
#
#
# Region: Hampton East (AUDs)
# Most Expensive Apartments:
# Price: 1471000.0, Number of Rooms: 4.0
# Price: 1416000.0, Number of Rooms: 5.0
# Price: 1345000.0, Number of Rooms: 4.0
# Price: 1335000.0, Number of Rooms: 4.0
# Price: 1300000.0, Number of Rooms: 4.0
# Least Expensive Apartments:
# Price: 830000.0, Number of Rooms: 3.0
# Price: 801000.0, Number of Rooms: 3.0
# Price: 771000.0, Number of Rooms: 3.0
# Price: 472000.0, Number of Rooms: 3.0
# Price: 400000.0, Number of Rooms: 3.0
#
#
# Region: Hawthorn (AUDs)
# Most Expensive Apartments:
# Price: 7650000.0, Number of Rooms: 5.0
# Price: 5510000.0, Number of Rooms: 6.0
# Price: 5100000.0, Number of Rooms: 4.0
# Price: 5050000.0, Number of Rooms: 5.0
# Price: 4250000.0, Number of Rooms: 6.0
# Least Expensive Apartments:
# Price: 300000.0, Number of Rooms: 2.0
# Price: 292000.0, Number of Rooms: 2.0
# Price: 290000.0, Number of Rooms: 2.0
# Price: 275000.0, Number of Rooms: 2.0
# Price: 160000.0, Number of Rooms: 2.0
#
#
# Region: Heidelberg Heights (AUDs)
# Most Expensive Apartments:
# Price: 1645000.0, Number of Rooms: 5.0
# Price: 1587500.0, Number of Rooms: 6.0
# Price: 1370000.0, Number of Rooms: 5.0
# Price: 1100000.0, Number of Rooms: 4.0
# Price: 1086000.0, Number of Rooms: 5.0
# Least Expensive Apartments:
# Price: 510000.0, Number of Rooms: 3.0
# Price: 460000.0, Number of Rooms: 3.0
# Price: 450000.0, Number of Rooms: 3.0
# Price: 440000.0, Number of Rooms: 3.0
# Price: 400000.0, Number of Rooms: 3.0
#
#
# Region: Heidelberg West (AUDs)
# Most Expensive Apartments:
# Price: 1375000.0, Number of Rooms: 4.0
# Price: 961000.0, Number of Rooms: 4.0
# Price: 950000.0, Number of Rooms: 4.0
# Price: 880000.0, Number of Rooms: 4.0
# Price: 875000.0, Number of Rooms: 3.0
# Least Expensive Apartments:
# Price: 405000.0, Number of Rooms: 2.0
# Price: 392000.0, Number of Rooms: 4.0
# Price: 370000.0, Number of Rooms: 3.0
# Price: 360000.0, Number of Rooms: 3.0
# Price: 330000.0, Number of Rooms: 4.0
#
#
# Region: Hughesdale (AUDs)
# Most Expensive Apartments:
# Price: 2190000.0, Number of Rooms: 5.0
# Price: 2120000.0, Number of Rooms: 5.0
# Price: 1745000.0, Number of Rooms: 5.0
# Price: 1700000.0, Number of Rooms: 5.0
# Price: 1570000.0, Number of Rooms: 5.0
# Least Expensive Apartments:
# Price: 472000.0, Number of Rooms: 3.0
# Price: 455000.0, Number of Rooms: 3.0
# Price: 420000.0, Number of Rooms: 3.0
# Price: 400000.0, Number of Rooms: 3.0
# Price: 375500.0, Number of Rooms: 3.0
#
#
# Region: Ivanhoe (AUDs)
# Most Expensive Apartments:
# Price: 3020000.0, Number of Rooms: 5.0
# Price: 2600000.0, Number of Rooms: 6.0
# Price: 2595000.0, Number of Rooms: 5.0
# Price: 2530000.0, Number of Rooms: 5.0
# Price: 2400000.0, Number of Rooms: 5.0
# Least Expensive Apartments:
# Price: 430000.0, Number of Rooms: 3.0
# Price: 421000.0, Number of Rooms: 2.0
# Price: 420000.0, Number of Rooms: 2.0
# Price: 413000.0, Number of Rooms: 2.0
# Price: 385000.0, Number of Rooms: 2.0
#
#
# Region: Kealba (AUDs)
# Most Expensive Apartments:
# Price: 1095000.0, Number of Rooms: 5.0
# Price: 751000.0, Number of Rooms: 5.0
# Price: 750000.0, Number of Rooms: 6.0
# Price: 740000.0, Number of Rooms: 5.0
# Price: 646000.0, Number of Rooms: 5.0
# Least Expensive Apartments:
# Price: 500000.0, Number of Rooms: 5.0
# Price: 461000.0, Number of Rooms: 4.0
# Price: 450000.0, Number of Rooms: 4.0
# Price: 365000.0, Number of Rooms: 4.0
# Price: 320000.0, Number of Rooms: 4.0
#
#
# Region: Keilor East (AUDs)
# Most Expensive Apartments:
# Price: 1475000.0, Number of Rooms: 5.0
# Price: 1420000.0, Number of Rooms: 5.0
# Price: 1295000.0, Number of Rooms: 4.0
# Price: 1250000.0, Number of Rooms: 5.0
# Price: 1230000.0, Number of Rooms: 5.0
# Least Expensive Apartments:
# Price: 490000.0, Number of Rooms: 3.0
# Price: 480000.0, Number of Rooms: 4.0
# Price: 470000.0, Number of Rooms: 3.0
# Price: 470000.0, Number of Rooms: 4.0
# Price: 380000.0, Number of Rooms: 3.0
#
#
# Region: Kensington (AUDs)
# Most Expensive Apartments:
# Price: 1900000.0, Number of Rooms: 6.0
# Price: 1817000.0, Number of Rooms: 5.0
# Price: 1817000.0, Number of Rooms: 5.0
# Price: 1710000.0, Number of Rooms: 6.0
# Price: 1675000.0, Number of Rooms: 5.0
# Least Expensive Apartments:
# Price: 370000.0, Number of Rooms: 2.0
# Price: 370000.0, Number of Rooms: 2.0
# Price: 365000.0, Number of Rooms: 2.0
# Price: 360000.0, Number of Rooms: 2.0
# Price: 355000.0, Number of Rooms: 2.0
#
#
# Region: Kew (AUDs)
# Most Expensive Apartments:
# Price: 6500000.0, Number of Rooms: 7.0
# Price: 5065000.0, Number of Rooms: 6.0
# Price: 4850000.0, Number of Rooms: 6.0
# Price: 4800000.0, Number of Rooms: 3.0
# Price: 4515000.0, Number of Rooms: 6.0
# Least Expensive Apartments:
# Price: 515000.0, Number of Rooms: 2.0
# Price: 480000.0, Number of Rooms: 3.0
# Price: 478000.0, Number of Rooms: 3.0
# Price: 468000.0, Number of Rooms: 2.0
# Price: 395000.0, Number of Rooms: 2.0
#
#
# Region: Kew East (AUDs)
# Most Expensive Apartments:
# Price: 3028000.0, Number of Rooms: 6.0
# Price: 2490000.0, Number of Rooms: 5.0
# Price: 2260000.0, Number of Rooms: 4.0
# Price: 2258000.0, Number of Rooms: 5.0
# Price: 2175000.0, Number of Rooms: 5.0
# Least Expensive Apartments:
# Price: 1110000.0, Number of Rooms: 3.0
# Price: 862000.0, Number of Rooms: 3.0
# Price: 620000.0, Number of Rooms: 3.0
# Price: 605000.0, Number of Rooms: 3.0
# Price: 590000.0, Number of Rooms: 3.0
#
#
# Region: Kooyong (AUDs)
# Most Expensive Apartments:
# Price: 3080000.0, Number of Rooms: 5.0
# Price: 1290000.0, Number of Rooms: 3.0
# Least Expensive Apartments:
# Price: 3080000.0, Number of Rooms: 5.0
# Price: 1290000.0, Number of Rooms: 3.0
#
#
# Region: Maidstone (AUDs)
# Most Expensive Apartments:
# Price: 1350000.0, Number of Rooms: 6.0
# Price: 1200000.0, Number of Rooms: 4.0
# Price: 1170000.0, Number of Rooms: 3.0
# Price: 1060000.0, Number of Rooms: 5.0
# Price: 1048000.0, Number of Rooms: 5.0
# Least Expensive Apartments:
# Price: 352500.0, Number of Rooms: 3.0
# Price: 349000.0, Number of Rooms: 3.0
# Price: 335000.0, Number of Rooms: 3.0
# Price: 280000.0, Number of Rooms: 2.0
# Price: 275000.0, Number of Rooms: 3.0
#
#
# Region: Malvern (AUDs)
# Most Expensive Apartments:
# Price: 4900000.0, Number of Rooms: 4.0
# Price: 4700000.0, Number of Rooms: 5.0
# Price: 4525000.0, Number of Rooms: 5.0
# Price: 4240000.0, Number of Rooms: 6.0
# Price: 4050000.0, Number of Rooms: 5.0
# Least Expensive Apartments:
# Price: 455000.0, Number of Rooms: 2.0
# Price: 420000.0, Number of Rooms: 2.0
# Price: 405000.0, Number of Rooms: 2.0
# Price: 365000.0, Number of Rooms: 2.0
# Price: 338000.0, Number of Rooms: 2.0
#
#
# Region: Malvern East (AUDs)
# Most Expensive Apartments:
# Price: 4802500.0, Number of Rooms: 6.0
# Price: 3600000.0, Number of Rooms: 5.0
# Price: 3200000.0, Number of Rooms: 5.0
# Price: 3000000.0, Number of Rooms: 5.0
# Price: 2960000.0, Number of Rooms: 5.0
# Least Expensive Apartments:
# Price: 370000.0, Number of Rooms: 3.0
# Price: 350000.0, Number of Rooms: 2.0
# Price: 315000.0, Number of Rooms: 2.0
# Price: 300000.0, Number of Rooms: 2.0
# Price: 267500.0, Number of Rooms: 2.0
#
#
# Region: Maribyrnong (AUDs)
# Most Expensive Apartments:
# Price: 3400000.0, Number of Rooms: 4.0
# Price: 1900000.0, Number of Rooms: 5.0
# Price: 1620000.0, Number of Rooms: 6.0
# Price: 1510500.0, Number of Rooms: 5.0
# Price: 1500000.0, Number of Rooms: 5.0
# Least Expensive Apartments:
# Price: 353000.0, Number of Rooms: 3.0
# Price: 335000.0, Number of Rooms: 3.0
# Price: 330000.0, Number of Rooms: 3.0
# Price: 330000.0, Number of Rooms: 3.0
# Price: 301000.0, Number of Rooms: 2.0
#
#
# Region: Melbourne (AUDs)
# Most Expensive Apartments:
# Price: 1850000.0, Number of Rooms: 5.0
# Price: 1630000.0, Number of Rooms: 4.0
# Price: 1160500.0, Number of Rooms: 3.0
# Price: 1075000.0, Number of Rooms: 3.0
# Price: 895000.0, Number of Rooms: 4.0
# Least Expensive Apartments:
# Price: 360000.0, Number of Rooms: 3.0
# Price: 360000.0, Number of Rooms: 3.0
# Price: 333000.0, Number of Rooms: 2.0
# Price: 275000.0, Number of Rooms: 2.0
# Price: 210000.0, Number of Rooms: 2.0
#
#
# Region: Middle Park (AUDs)
# Most Expensive Apartments:
# Price: 6400000.0, Number of Rooms: 6.0
# Price: 5600000.0, Number of Rooms: 7.0
# Price: 3750000.0, Number of Rooms: 4.0
# Price: 3120000.0, Number of Rooms: 5.0
# Price: 2956000.0, Number of Rooms: 4.0
# Least Expensive Apartments:
# Price: 1020000.0, Number of Rooms: 3.0
# Price: 702000.0, Number of Rooms: 3.0
# Price: 700000.0, Number of Rooms: 3.0
# Price: 535000.0, Number of Rooms: 3.0
# Price: 400000.0, Number of Rooms: 2.0
#
#
# Region: Mont Albert (AUDs)
# Most Expensive Apartments:
# Price: 3900000.0, Number of Rooms: 5.0
# Price: 2850000.0, Number of Rooms: 5.0
# Price: 2714000.0, Number of Rooms: 6.0
# Price: 2588000.0, Number of Rooms: 4.0
# Price: 2500000.0, Number of Rooms: 5.0
# Least Expensive Apartments:
# Price: 665000.0, Number of Rooms: 3.0
# Price: 660000.0, Number of Rooms: 3.0
# Price: 540000.0, Number of Rooms: 3.0
# Price: 520000.0, Number of Rooms: 3.0
# Price: 442500.0, Number of Rooms: 3.0
#
#
# Region: Moonee Ponds (AUDs)
# Most Expensive Apartments:
# Price: 2405000.0, Number of Rooms: 6.0
# Price: 2400000.0, Number of Rooms: 5.0
# Price: 2340000.0, Number of Rooms: 6.0
# Price: 2300000.0, Number of Rooms: 6.0
# Price: 2150000.0, Number of Rooms: 7.0
# Least Expensive Apartments:
# Price: 296000.0, Number of Rooms: 2.0
# Price: 292000.0, Number of Rooms: 2.0
# Price: 286000.0, Number of Rooms: 2.0
# Price: 265000.0, Number of Rooms: 2.0
# Price: 222000.0, Number of Rooms: 2.0
#
#
# Region: Moorabbin (AUDs)
# Most Expensive Apartments:
# Price: 1426000.0, Number of Rooms: 5.0
# Price: 1417250.0, Number of Rooms: 4.0
# Price: 1401500.0, Number of Rooms: 4.0
# Price: 1385000.0, Number of Rooms: 5.0
# Price: 1321000.0, Number of Rooms: 4.0
# Least Expensive Apartments:
# Price: 655000.0, Number of Rooms: 3.0
# Price: 639000.0, Number of Rooms: 3.0
# Price: 605000.0, Number of Rooms: 3.0
# Price: 380500.0, Number of Rooms: 2.0
# Price: 240000.0, Number of Rooms: 2.0
#
#
# Region: Newport (AUDs)
# Most Expensive Apartments:
# Price: 3420000.0, Number of Rooms: 5.0
# Price: 2415000.0, Number of Rooms: 6.0
# Price: 2337000.0, Number of Rooms: 5.0
# Price: 2015000.0, Number of Rooms: 6.0
# Price: 2000000.0, Number of Rooms: 4.0
# Least Expensive Apartments:
# Price: 600000.0, Number of Rooms: 3.0
# Price: 582000.0, Number of Rooms: 3.0
# Price: 485000.0, Number of Rooms: 3.0
# Price: 485000.0, Number of Rooms: 3.0
# Price: 335000.0, Number of Rooms: 2.0
#
#
# Region: Niddrie (AUDs)
# Most Expensive Apartments:
# Price: 1751000.0, Number of Rooms: 5.0
# Price: 1450000.0, Number of Rooms: 4.0
# Price: 1405000.0, Number of Rooms: 2.0
# Price: 1400000.0, Number of Rooms: 6.0
# Price: 1370000.0, Number of Rooms: 3.0
# Least Expensive Apartments:
# Price: 510000.0, Number of Rooms: 3.0
# Price: 500000.0, Number of Rooms: 4.0
# Price: 490000.0, Number of Rooms: 3.0
# Price: 457000.0, Number of Rooms: 3.0
# Price: 325000.0, Number of Rooms: 2.0
#
#
# Region: North Melbourne (AUDs)
# Most Expensive Apartments:
# Price: 2920000.0, Number of Rooms: 5.0
# Price: 2161000.0, Number of Rooms: 4.0
# Price: 1803000.0, Number of Rooms: 3.0
# Price: 1746000.0, Number of Rooms: 5.0
# Price: 1635000.0, Number of Rooms: 4.0
# Least Expensive Apartments:
# Price: 410000.0, Number of Rooms: 2.0
# Price: 368000.0, Number of Rooms: 2.0
# Price: 358000.0, Number of Rooms: 2.0
# Price: 340000.0, Number of Rooms: 2.0
# Price: 320000.0, Number of Rooms: 2.0
#
#
# Region: Northcote (AUDs)
# Most Expensive Apartments:
# Price: 4300000.0, Number of Rooms: 6.0
# Price: 3850000.0, Number of Rooms: 5.0
# Price: 2990000.0, Number of Rooms: 5.0
# Price: 2775000.0, Number of Rooms: 4.0
# Price: 2700000.0, Number of Rooms: 6.0
# Least Expensive Apartments:
# Price: 352500.0, Number of Rooms: 2.0
# Price: 340000.0, Number of Rooms: 2.0
# Price: 320000.0, Number of Rooms: 2.0
# Price: 312000.0, Number of Rooms: 2.0
# Price: 280000.0, Number of Rooms: 2.0
#
#
# Region: Oak Park (AUDs)
# Most Expensive Apartments:
# Price: 1453000.0, Number of Rooms: 5.0
# Price: 1400000.0, Number of Rooms: 4.0
# Price: 1350000.0, Number of Rooms: 5.0
# Price: 1306000.0, Number of Rooms: 6.0
# Price: 1300000.0, Number of Rooms: 5.0
# Least Expensive Apartments:
# Price: 476000.0, Number of Rooms: 3.0
# Price: 475000.0, Number of Rooms: 3.0
# Price: 470000.0, Number of Rooms: 3.0
# Price: 460000.0, Number of Rooms: 3.0
# Price: 358500.0, Number of Rooms: 4.0
#
#
# Region: Oakleigh South (AUDs)
# Most Expensive Apartments:
# Price: 1900000.0, Number of Rooms: 7.0
# Price: 1500000.0, Number of Rooms: 5.0
# Price: 1450000.0, Number of Rooms: 5.0
# Price: 1410000.0, Number of Rooms: 5.0
# Price: 1390000.0, Number of Rooms: 5.0
# Least Expensive Apartments:
# Price: 680000.0, Number of Rooms: 4.0
# Price: 651000.0, Number of Rooms: 5.0
# Price: 625000.0, Number of Rooms: 3.0
# Price: 601000.0, Number of Rooms: 3.0
# Price: 580000.0, Number of Rooms: 3.0
#
#
# Region: Parkville (AUDs)
# Most Expensive Apartments:
# Price: 3970000.0, Number of Rooms: 5.0
# Price: 2790000.0, Number of Rooms: 4.0
# Price: 2375000.0, Number of Rooms: 5.0
# Price: 2236000.0, Number of Rooms: 4.0
# Price: 2200000.0, Number of Rooms: 3.0
# Least Expensive Apartments:
# Price: 485000.0, Number of Rooms: 2.0
# Price: 401000.0, Number of Rooms: 2.0
# Price: 395000.0, Number of Rooms: 2.0
# Price: 352500.0, Number of Rooms: 2.0
# Price: 307000.0, Number of Rooms: 2.0
#
#
# Region: Pascoe Vale (AUDs)
# Most Expensive Apartments:
# Price: 1663000.0, Number of Rooms: 4.0
# Price: 1570000.0, Number of Rooms: 3.0
# Price: 1501000.0, Number of Rooms: 6.0
# Price: 1465000.0, Number of Rooms: 4.0
# Price: 1410000.0, Number of Rooms: 6.0
# Least Expensive Apartments:
# Price: 386000.0, Number of Rooms: 3.0
# Price: 360000.0, Number of Rooms: 3.0
# Price: 257500.0, Number of Rooms: 2.0
# Price: 257500.0, Number of Rooms: 2.0
# Price: 248500.0, Number of Rooms: 2.0
#
#
# Region: Port Melbourne (AUDs)
# Most Expensive Apartments:
# Price: 3705000.0, Number of Rooms: 4.0
# Price: 2730000.0, Number of Rooms: 4.0
# Price: 2700000.0, Number of Rooms: 5.0
# Price: 2625000.0, Number of Rooms: 5.0
# Price: 2460000.0, Number of Rooms: 4.0
# Least Expensive Apartments:
# Price: 470000.0, Number of Rooms: 2.0
# Price: 456000.0, Number of Rooms: 2.0
# Price: 455500.0, Number of Rooms: 2.0
# Price: 420000.0, Number of Rooms: 2.0
# Price: 400000.0, Number of Rooms: 2.0
#
#
# Region: Prahran (AUDs)
# Most Expensive Apartments:
# Price: 4200000.0, Number of Rooms: 5.0
# Price: 2668000.0, Number of Rooms: 5.0
# Price: 2635000.0, Number of Rooms: 5.0
# Price: 2385000.0, Number of Rooms: 4.0
# Price: 2300000.0, Number of Rooms: 5.0
# Least Expensive Apartments:
# Price: 399000.0, Number of Rooms: 2.0
# Price: 342000.0, Number of Rooms: 2.0
# Price: 330000.0, Number of Rooms: 2.0
# Price: 325000.0, Number of Rooms: 2.0
# Price: 240000.0, Number of Rooms: 2.0
#
#
# Region: Preston (AUDs)
# Most Expensive Apartments:
# Price: 2300000.0, Number of Rooms: 3.0
# Price: 2000000.0, Number of Rooms: 3.0
# Price: 1650000.0, Number of Rooms: 4.0
# Price: 1615000.0, Number of Rooms: 5.0
# Price: 1485000.0, Number of Rooms: 5.0
# Least Expensive Apartments:
# Price: 392000.0, Number of Rooms: 2.0
# Price: 385000.0, Number of Rooms: 2.0
# Price: 305000.0, Number of Rooms: 2.0
# Price: 300000.0, Number of Rooms: 2.0
# Price: 250000.0, Number of Rooms: 2.0
#
#
# Region: Reservoir (AUDs)
# Most Expensive Apartments:
# Price: 1700000.0, Number of Rooms: 5.0
# Price: 1700000.0, Number of Rooms: 3.0
# Price: 1400000.0, Number of Rooms: 4.0
# Price: 1282500.0, Number of Rooms: 6.0
# Price: 1266000.0, Number of Rooms: 6.0
# Least Expensive Apartments:
# Price: 270000.0, Number of Rooms: 2.0
# Price: 260000.0, Number of Rooms: 2.0
# Price: 240000.0, Number of Rooms: 3.0
# Price: 220000.0, Number of Rooms: 2.0
# Price: 216000.0, Number of Rooms: 2.0
#
#
# Region: Richmond (AUDs)
# Most Expensive Apartments:
# Price: 3335000.0, Number of Rooms: 5.0
# Price: 3200000.0, Number of Rooms: 6.0
# Price: 3020000.0, Number of Rooms: 4.0
# Price: 3001000.0, Number of Rooms: 5.0
# Price: 3000000.0, Number of Rooms: 4.0
# Least Expensive Apartments:
# Price: 330000.0, Number of Rooms: 2.0
# Price: 327000.0, Number of Rooms: 2.0
# Price: 314000.0, Number of Rooms: 2.0
# Price: 306000.0, Number of Rooms: 2.0
# Price: 270000.0, Number of Rooms: 3.0
#
#
# Region: Rosanna (AUDs)
# Most Expensive Apartments:
# Price: 2530000.0, Number of Rooms: 6.0
# Price: 1800000.0, Number of Rooms: 5.0
# Price: 1775000.0, Number of Rooms: 5.0
# Price: 1720000.0, Number of Rooms: 5.0
# Price: 1610000.0, Number of Rooms: 5.0
# Least Expensive Apartments:
# Price: 531000.0, Number of Rooms: 3.0
# Price: 515000.0, Number of Rooms: 3.0
# Price: 515000.0, Number of Rooms: 4.0
# Price: 452000.0, Number of Rooms: 3.0
# Price: 430000.0, Number of Rooms: 3.0
#
#
# Region: Seddon (AUDs)
# Most Expensive Apartments:
# Price: 1870000.0, Number of Rooms: 5.0
# Price: 1502000.0, Number of Rooms: 5.0
# Price: 1455000.0, Number of Rooms: 5.0
# Price: 1395000.0, Number of Rooms: 4.0
# Price: 1350000.0, Number of Rooms: 4.0
# Least Expensive Apartments:
# Price: 533000.0, Number of Rooms: 3.0
# Price: 450000.0, Number of Rooms: 3.0
# Price: 355000.0, Number of Rooms: 3.0
# Price: 322500.0, Number of Rooms: 2.0
# Price: 215000.0, Number of Rooms: 2.0
#
#
# Region: South Melbourne (AUDs)
# Most Expensive Apartments:
# Price: 4100000.0, Number of Rooms: 5.0
# Price: 3825000.0, Number of Rooms: 5.0
# Price: 2800000.0, Number of Rooms: 4.0
# Price: 2633000.0, Number of Rooms: 4.0
# Price: 2525000.0, Number of Rooms: 4.0
# Least Expensive Apartments:
# Price: 480000.0, Number of Rooms: 2.0
# Price: 460000.0, Number of Rooms: 2.0
# Price: 407500.0, Number of Rooms: 2.0
# Price: 380000.0, Number of Rooms: 2.0
# Price: 320000.0, Number of Rooms: 2.0
#
#
# Region: South Yarra (AUDs)
# Most Expensive Apartments:
# Price: 5700000.0, Number of Rooms: 5.0
# Price: 3475000.0, Number of Rooms: 4.0
# Price: 3000000.0, Number of Rooms: 4.0
# Price: 2920000.0, Number of Rooms: 5.0
# Price: 2870000.0, Number of Rooms: 4.0
# Least Expensive Apartments:
# Price: 315000.0, Number of Rooms: 2.0
# Price: 310000.0, Number of Rooms: 2.0
# Price: 310000.0, Number of Rooms: 2.0
# Price: 280000.0, Number of Rooms: 2.0
# Price: 260800.0, Number of Rooms: 2.0
#
#
# Region: Southbank (AUDs)
# Most Expensive Apartments:
# Price: 1250000.0, Number of Rooms: 5.0
# Price: 1220000.0, Number of Rooms: 4.0
# Price: 990000.0, Number of Rooms: 5.0
# Price: 868000.0, Number of Rooms: 4.0
# Price: 815000.0, Number of Rooms: 3.0
# Least Expensive Apartments:
# Price: 425000.0, Number of Rooms: 2.0
# Price: 422500.0, Number of Rooms: 2.0
# Price: 422000.0, Number of Rooms: 2.0
# Price: 385500.0, Number of Rooms: 2.0
# Price: 370000.0, Number of Rooms: 2.0
#
#
# Region: Spotswood (AUDs)
# Most Expensive Apartments:
# Price: 1320000.0, Number of Rooms: 4.0
# Price: 1315000.0, Number of Rooms: 5.0
# Price: 1300000.0, Number of Rooms: 5.0
# Price: 1170000.0, Number of Rooms: 5.0
# Price: 1161000.0, Number of Rooms: 5.0
# Least Expensive Apartments:
# Price: 782500.0, Number of Rooms: 3.0
# Price: 775000.0, Number of Rooms: 4.0
# Price: 690000.0, Number of Rooms: 4.0
# Price: 660000.0, Number of Rooms: 4.0
# Price: 380000.0, Number of Rooms: 2.0
#
#
# Region: St Kilda (AUDs)
# Most Expensive Apartments:
# Price: 5046000.0, Number of Rooms: 6.0
# Price: 4750000.0, Number of Rooms: 5.0
# Price: 4400000.0, Number of Rooms: 6.0
# Price: 2720000.0, Number of Rooms: 4.0
# Price: 2680000.0, Number of Rooms: 5.0
# Least Expensive Apartments:
# Price: 346000.0, Number of Rooms: 2.0
# Price: 335000.0, Number of Rooms: 2.0
# Price: 330000.0, Number of Rooms: 2.0
# Price: 320000.0, Number of Rooms: 2.0
# Price: 320000.0, Number of Rooms: 2.0
#
#
# Region: Strathmore (AUDs)
# Most Expensive Apartments:
# Price: 2650000.0, Number of Rooms: 6.0
# Price: 2000000.0, Number of Rooms: 8.0
# Price: 1848000.0, Number of Rooms: 4.0
# Price: 1780000.0, Number of Rooms: 6.0
# Price: 1742000.0, Number of Rooms: 4.0
# Least Expensive Apartments:
# Price: 646000.0, Number of Rooms: 3.0
# Price: 630000.0, Number of Rooms: 3.0
# Price: 622500.0, Number of Rooms: 4.0
# Price: 600000.0, Number of Rooms: 4.0
# Price: 535000.0, Number of Rooms: 3.0
#
#
# Region: Sunshine (AUDs)
# Most Expensive Apartments:
# Price: 1350500.0, Number of Rooms: 5.0
# Price: 1070000.0, Number of Rooms: 4.0
# Price: 1030000.0, Number of Rooms: 5.0
# Price: 1001000.0, Number of Rooms: 4.0
# Price: 1001000.0, Number of Rooms: 5.0
# Least Expensive Apartments:
# Price: 425500.0, Number of Rooms: 3.0
# Price: 425000.0, Number of Rooms: 3.0
# Price: 410000.0, Number of Rooms: 3.0
# Price: 260000.0, Number of Rooms: 3.0
# Price: 245000.0, Number of Rooms: 2.0
#
#
# Region: Sunshine North (AUDs)
# Most Expensive Apartments:
# Price: 1190000.0, Number of Rooms: 3.0
# Price: 1000000.0, Number of Rooms: 6.0
# Price: 905000.0, Number of Rooms: 4.0
# Price: 895000.0, Number of Rooms: 5.0
# Price: 871000.0, Number of Rooms: 4.0
# Least Expensive Apartments:
# Price: 480000.0, Number of Rooms: 4.0
# Price: 435000.0, Number of Rooms: 3.0
# Price: 432500.0, Number of Rooms: 4.0
# Price: 429000.0, Number of Rooms: 3.0
# Price: 315000.0, Number of Rooms: 3.0
#
#
# Region: Sunshine West (AUDs)
# Most Expensive Apartments:
# Price: 859000.0, Number of Rooms: 5.0
# Price: 825000.0, Number of Rooms: 4.0
# Price: 795000.0, Number of Rooms: 4.0
# Price: 780000.0, Number of Rooms: 5.0
# Price: 765000.0, Number of Rooms: 5.0
# Least Expensive Apartments:
# Price: 450000.0, Number of Rooms: 4.0
# Price: 450000.0, Number of Rooms: 4.0
# Price: 350000.0, Number of Rooms: 3.0
# Price: 305000.0, Number of Rooms: 4.0
# Price: 280000.0, Number of Rooms: 2.0
#
#
# Region: Surrey Hills (AUDs)
# Most Expensive Apartments:
# Price: 3625000.0, Number of Rooms: 6.0
# Price: 3100000.0, Number of Rooms: 5.0
# Price: 2860000.0, Number of Rooms: 5.0
# Price: 2760000.0, Number of Rooms: 5.0
# Price: 2720000.0, Number of Rooms: 5.0
# Least Expensive Apartments:
# Price: 600000.0, Number of Rooms: 3.0
# Price: 600000.0, Number of Rooms: 3.0
# Price: 562500.0, Number of Rooms: 3.0
# Price: 550000.0, Number of Rooms: 3.0
# Price: 520000.0, Number of Rooms: 3.0
#
#
# Region: Templestowe Lower (AUDs)
# Most Expensive Apartments:
# Price: 2080000.0, Number of Rooms: 6.0
# Price: 2025000.0, Number of Rooms: 4.0
# Price: 2000000.0, Number of Rooms: 7.0
# Price: 1775000.0, Number of Rooms: 6.0
# Price: 1745000.0, Number of Rooms: 5.0
# Least Expensive Apartments:
# Price: 731000.0, Number of Rooms: 3.0
# Price: 725000.0, Number of Rooms: 4.0
# Price: 678000.0, Number of Rooms: 3.0
# Price: 650000.0, Number of Rooms: 4.0
# Price: 641000.0, Number of Rooms: 4.0
#
#
# Region: Thornbury (AUDs)
# Most Expensive Apartments:
# Price: 2070000.0, Number of Rooms: 5.0
# Price: 1913000.0, Number of Rooms: 4.0
# Price: 1750000.0, Number of Rooms: 4.0
# Price: 1635000.0, Number of Rooms: 5.0
# Price: 1626000.0, Number of Rooms: 5.0
# Least Expensive Apartments:
# Price: 295000.0, Number of Rooms: 2.0
# Price: 277500.0, Number of Rooms: 2.0
# Price: 270000.0, Number of Rooms: 2.0
# Price: 260000.0, Number of Rooms: 2.0
# Price: 245000.0, Number of Rooms: 2.0
#
#
# Region: Toorak (AUDs)
# Most Expensive Apartments:
# Price: 6250000.0, Number of Rooms: 4.0
# Price: 5500000.0, Number of Rooms: 5.0
# Price: 5500000.0, Number of Rooms: 5.0
# Price: 4500000.0, Number of Rooms: 5.0
# Price: 4200000.0, Number of Rooms: 4.0
# Least Expensive Apartments:
# Price: 366000.0, Number of Rooms: 2.0
# Price: 350000.0, Number of Rooms: 2.0
# Price: 349000.0, Number of Rooms: 2.0
# Price: 345000.0, Number of Rooms: 2.0
# Price: 247500.0, Number of Rooms: 2.0
#
#
# Region: Viewbank (AUDs)
# Most Expensive Apartments:
# Price: 1612000.0, Number of Rooms: 5.0
# Price: 1316000.0, Number of Rooms: 6.0
# Price: 1295000.0, Number of Rooms: 5.0
# Price: 1155000.0, Number of Rooms: 5.0
# Price: 1140000.0, Number of Rooms: 5.0
# Least Expensive Apartments:
# Price: 730000.0, Number of Rooms: 5.0
# Price: 556000.0, Number of Rooms: 3.0
# Price: 555000.0, Number of Rooms: 3.0
# Price: 546000.0, Number of Rooms: 3.0
# Price: 440000.0, Number of Rooms: 4.0
#
#
# Region: Watsonia (AUDs)
# Most Expensive Apartments:
# Price: 1171000.0, Number of Rooms: 5.0
# Price: 1040000.0, Number of Rooms: 4.0
# Price: 1010000.0, Number of Rooms: 4.0
# Price: 1000000.0, Number of Rooms: 4.0
# Price: 952000.0, Number of Rooms: 5.0
# Least Expensive Apartments:
# Price: 581000.0, Number of Rooms: 4.0
# Price: 549000.0, Number of Rooms: 4.0
# Price: 537000.0, Number of Rooms: 4.0
# Price: 485000.0, Number of Rooms: 3.0
# Price: 342500.0, Number of Rooms: 3.0
#
#
# Region: West Melbourne (AUDs)
# Most Expensive Apartments:
# ...
# Price: 471000.0, Number of Rooms: 4.0
#
#
# Region: Albanvale (AUDs)
# Most Expensive Apartments:
# Price: 655000.0, Number of Rooms: 5.0
# Price: 565000.0, Number of Rooms: 4.0
# Price: 555000.0, Number of Rooms: 4.0
# Price: 526500.0, Number of Rooms: 4.0
# Price: 506000.0, Number of Rooms: 4.0
# Least Expensive Apartments:
# Price: 565000.0, Number of Rooms: 4.0
# Price: 555000.0, Number of Rooms: 4.0
# Price: 526500.0, Number of Rooms: 4.0
# Price: 506000.0, Number of Rooms: 4.0
# Price: 415000.0, Number of Rooms: 3.0
#
#
# Region: Beaconsfield Upper (AUDs)
# Most Expensive Apartments:
# Price: 675000.0, Number of Rooms: 5.0
# Least Expensive Apartments:
# Price: 675000.0, Number of Rooms: 5.0
#
#
# Region: Chelsea Heights (AUDs)
# Most Expensive Apartments:
# Price: 835500.0, Number of Rooms: 6.0
# Price: 732000.0, Number of Rooms: 5.0
# Price: 725000.0, Number of Rooms: 4.0
# Price: 710000.0, Number of Rooms: 4.0
# Least Expensive Apartments:
# Price: 835500.0, Number of Rooms: 6.0
# Price: 732000.0, Number of Rooms: 5.0
# Price: 725000.0, Number of Rooms: 4.0
# Price: 710000.0, Number of Rooms: 4.0
#
#
# Region: Dallas (AUDs)
# Most Expensive Apartments:
# Price: 477000.0, Number of Rooms: 4.0
# Price: 475000.0, Number of Rooms: 4.0
# Price: 459000.0, Number of Rooms: 4.0
# Price: 420500.0, Number of Rooms: 4.0
# Price: 408500.0, Number of Rooms: 4.0
# Least Expensive Apartments:
# Price: 475000.0, Number of Rooms: 4.0
# Price: 459000.0, Number of Rooms: 4.0
# Price: 420500.0, Number of Rooms: 4.0
# Price: 408500.0, Number of Rooms: 4.0
# Price: 310000.0, Number of Rooms: 4.0
#
#
# Region: Deer Park (AUDs)
# Most Expensive Apartments:
# Price: 716000.0, Number of Rooms: 4.0
# Price: 665000.0, Number of Rooms: 4.0
# Price: 650000.0, Number of Rooms: 5.0
# Price: 650000.0, Number of Rooms: 4.0
# Price: 645000.0, Number of Rooms: 4.0
# Least Expensive Apartments:
# Price: 572000.0, Number of Rooms: 4.0
# Price: 570000.0, Number of Rooms: 4.0
# Price: 557000.0, Number of Rooms: 4.0
# Price: 535000.0, Number of Rooms: 4.0
# Price: 447000.0, Number of Rooms: 5.0
#
#
# Region: Eltham North (AUDs)
# Most Expensive Apartments:
# Price: 1115000.0, Number of Rooms: 7.0
# Price: 967500.0, Number of Rooms: 4.0
# Price: 950000.0, Number of Rooms: 5.0
# Price: 925000.0, Number of Rooms: 5.0
# Price: 920000.0, Number of Rooms: 5.0
# Least Expensive Apartments:
# Price: 890000.0, Number of Rooms: 5.0
# Price: 881017.0, Number of Rooms: 4.0
# Price: 850000.0, Number of Rooms: 5.0
# Price: 850000.0, Number of Rooms: 6.0
# Price: 792000.0, Number of Rooms: 5.0
#
#
# Region: Keilor (AUDs)
# Most Expensive Apartments:
# Price: 1125000.0, Number of Rooms: 5.0
# Price: 930000.0, Number of Rooms: 4.0
# Price: 895000.0, Number of Rooms: 4.0
# Price: 875000.0, Number of Rooms: 4.0
# Price: 840000.0, Number of Rooms: 4.0
# Least Expensive Apartments:
# Price: 840000.0, Number of Rooms: 4.0
# Price: 775000.0, Number of Rooms: 4.0
# Price: 739000.0, Number of Rooms: 6.0
# Price: 678500.0, Number of Rooms: 4.0
# Price: 635000.0, Number of Rooms: 5.0
#
#
# Region: Meadow Heights (AUDs)
# Most Expensive Apartments:
# Price: 741000.0, Number of Rooms: 9.0
# Price: 570000.0, Number of Rooms: 5.0
# Price: 560000.0, Number of Rooms: 5.0
# Price: 535000.0, Number of Rooms: 4.0
# Price: 520000.0, Number of Rooms: 4.0
# Least Expensive Apartments:
# Price: 440000.0, Number of Rooms: 4.0
# Price: 430000.0, Number of Rooms: 4.0
# Price: 420000.0, Number of Rooms: 4.0
# Price: 370000.0, Number of Rooms: 4.0
# Price: 360000.0, Number of Rooms: 4.0
#
#
# Region: Mount Evelyn (AUDs)
# Most Expensive Apartments:
# Price: 620000.0, Number of Rooms: 4.0
# Price: 515000.0, Number of Rooms: 4.0
# Least Expensive Apartments:
# Price: 620000.0, Number of Rooms: 4.0
# Price: 515000.0, Number of Rooms: 4.0
#
#
# Region: North Warrandyte (AUDs)
# Most Expensive Apartments:
# Price: 1550000.0, Number of Rooms: 6.0
# Price: 902000.0, Number of Rooms: 5.0
# Least Expensive Apartments:
# Price: 1550000.0, Number of Rooms: 6.0
# Price: 902000.0, Number of Rooms: 5.0
#
#
# Region: Pakenham (AUDs)
# Most Expensive Apartments:
# Price: 643500.0, Number of Rooms: 5.0
# Price: 435000.0, Number of Rooms: 5.0
# Price: 410500.0, Number of Rooms: 5.0
# Least Expensive Apartments:
# Price: 643500.0, Number of Rooms: 5.0
# Price: 435000.0, Number of Rooms: 5.0
# Price: 410500.0, Number of Rooms: 5.0
#
#
# Region: Riddells Creek (AUDs)
# Most Expensive Apartments:
# Price: 817000.0, Number of Rooms: 5.0
# Least Expensive Apartments:
# Price: 817000.0, Number of Rooms: 5.0
#
#
# Region: Sandhurst (AUDs)
# Most Expensive Apartments:
# Price: 645000.0, Number of Rooms: 5.0
# Least Expensive Apartments:
# Price: 645000.0, Number of Rooms: 5.0
#
#
# Region: Scoresby (AUDs)
# Most Expensive Apartments:
# Price: 1120000.0, Number of Rooms: 5.0
# Price: 1040000.0, Number of Rooms: 5.0
# Price: 1000000.0, Number of Rooms: 4.0
# Price: 962000.0, Number of Rooms: 5.0
# Price: 950000.0, Number of Rooms: 5.0
# Least Expensive Apartments:
# Price: 962000.0, Number of Rooms: 5.0
# Price: 950000.0, Number of Rooms: 5.0
# Price: 890000.0, Number of Rooms: 4.0
# Price: 870000.0, Number of Rooms: 4.0
# Price: 833800.0, Number of Rooms: 4.0
#
#
# Region: Silvan (AUDs)
# Most Expensive Apartments:
# Price: 1085000.0, Number of Rooms: 4.0
# Price: 1070000.0, Number of Rooms: 5.0
# Least Expensive Apartments:
# Price: 1085000.0, Number of Rooms: 4.0
# Price: 1070000.0, Number of Rooms: 5.0
#
#
# Region: Aspendale (AUDs)
# Most Expensive Apartments:
# Price: 1510000.0, Number of Rooms: 5.0
# Price: 1362000.0, Number of Rooms: 5.0
# Price: 1300000.0, Number of Rooms: 4.0
# Price: 1150000.0, Number of Rooms: 5.0
# Price: 970000.0, Number of Rooms: 4.0
# Least Expensive Apartments:
# Price: 1300000.0, Number of Rooms: 4.0
# Price: 1150000.0, Number of Rooms: 5.0
# Price: 970000.0, Number of Rooms: 4.0
# Price: 805000.0, Number of Rooms: 4.0
# Price: 780000.0, Number of Rooms: 4.0
#
#
# Region: Chirnside Park (AUDs)
# Most Expensive Apartments:
# Price: 911982.0, Number of Rooms: 5.0
# Price: 640000.0, Number of Rooms: 4.0
# Least Expensive Apartments:
# Price: 911982.0, Number of Rooms: 5.0
# Price: 640000.0, Number of Rooms: 4.0
#
#
# Region: Croydon Hills (AUDs)
# Most Expensive Apartments:
# Price: 1020000.0, Number of Rooms: 5.0
# Price: 931000.0, Number of Rooms: 4.0
# Price: 905000.0, Number of Rooms: 5.0
# Price: 790000.0, Number of Rooms: 4.0
# Least Expensive Apartments:
# Price: 1020000.0, Number of Rooms: 5.0
# Price: 931000.0, Number of Rooms: 4.0
# Price: 905000.0, Number of Rooms: 5.0
# Price: 790000.0, Number of Rooms: 4.0
#
#
# Region: Croydon South (AUDs)
# Most Expensive Apartments:
# Price: 800000.0, Number of Rooms: 4.0
# Least Expensive Apartments:
# Price: 800000.0, Number of Rooms: 4.0
#
#
# Region: Derrimut (AUDs)
# Most Expensive Apartments:
# Price: 860000.0, Number of Rooms: 5.0
# Price: 750000.0, Number of Rooms: 5.0
# Price: 695000.0, Number of Rooms: 5.0
# Price: 630000.0, Number of Rooms: 4.0
# Price: 610000.0, Number of Rooms: 5.0
# Least Expensive Apartments:
# Price: 860000.0, Number of Rooms: 5.0
# Price: 750000.0, Number of Rooms: 5.0
# Price: 695000.0, Number of Rooms: 5.0
# Price: 630000.0, Number of Rooms: 4.0
# Price: 610000.0, Number of Rooms: 5.0
#
#
# Region: Diggers Rest (AUDs)
# Most Expensive Apartments:
# Price: 615000.0, Number of Rooms: 7.0
# Price: 435000.0, Number of Rooms: 4.0
# Least Expensive Apartments:
# Price: 615000.0, Number of Rooms: 7.0
# Price: 435000.0, Number of Rooms: 4.0
#
#
# Region: Edithvale (AUDs)
# Most Expensive Apartments:
# Price: 1850000.0, Number of Rooms: 7.0
# Price: 1260000.0, Number of Rooms: 6.0
# Price: 1100000.0, Number of Rooms: 4.0
# Price: 950000.0, Number of Rooms: 4.0
# Price: 875000.0, Number of Rooms: 4.0
# Least Expensive Apartments:
# Price: 875000.0, Number of Rooms: 4.0
# Price: 837000.0, Number of Rooms: 4.0
# Price: 724000.0, Number of Rooms: 3.0
# Price: 700000.0, Number of Rooms: 5.0
# Price: 612500.0, Number of Rooms: 3.0
#
#
# Region: Hampton Park (AUDs)
# Most Expensive Apartments:
# Price: 625000.0, Number of Rooms: 5.0
# Price: 622000.0, Number of Rooms: 5.0
# Price: 561000.0, Number of Rooms: 4.0
# Price: 400000.0, Number of Rooms: 4.0
# Least Expensive Apartments:
# Price: 625000.0, Number of Rooms: 5.0
# Price: 622000.0, Number of Rooms: 5.0
# Price: 561000.0, Number of Rooms: 4.0
# Price: 400000.0, Number of Rooms: 4.0
#
#
# Region: Knoxfield (AUDs)
# Most Expensive Apartments:
# Price: 1218000.0, Number of Rooms: 5.0
# Price: 1070000.0, Number of Rooms: 6.0
# Price: 1040000.0, Number of Rooms: 5.0
# Price: 1010000.0, Number of Rooms: 5.0
# Least Expensive Apartments:
# Price: 1218000.0, Number of Rooms: 5.0
# Price: 1070000.0, Number of Rooms: 6.0
# Price: 1040000.0, Number of Rooms: 5.0
# Price: 1010000.0, Number of Rooms: 5.0
#
#
# Region: St Helena (AUDs)
# Most Expensive Apartments:
# Price: 1387000.0, Number of Rooms: 6.0
# Price: 897000.0, Number of Rooms: 4.0
# Price: 805000.0, Number of Rooms: 4.0
# Least Expensive Apartments:
# Price: 1387000.0, Number of Rooms: 6.0
# Price: 897000.0, Number of Rooms: 4.0
# Price: 805000.0, Number of Rooms: 4.0
#
#
# Region: Upwey (AUDs)
# Most Expensive Apartments:
# Price: 575000.0, Number of Rooms: 3.0
# Least Expensive Apartments:
# Price: 575000.0, Number of Rooms: 3.0
#
#
# Region: Bacchus Marsh (AUDs)
# Most Expensive Apartments:
# Price: 285000.0, Number of Rooms: 4.0
# Least Expensive Apartments:
# Price: 285000.0, Number of Rooms: 4.0
#
#
# Region: Coolaroo (AUDs)
# Most Expensive Apartments:
# Price: 515000.0, Number of Rooms: 5.0
# Price: 460000.0, Number of Rooms: 4.0
# Price: 457000.0, Number of Rooms: 4.0
# Price: 455000.0, Number of Rooms: 4.0
# Least Expensive Apartments:
# Price: 515000.0, Number of Rooms: 5.0
# Price: 460000.0, Number of Rooms: 4.0
# Price: 457000.0, Number of Rooms: 4.0
# Price: 455000.0, Number of Rooms: 4.0
#
#
# Region: Cranbourne North (AUDs)
# Most Expensive Apartments:
# Price: 670000.0, Number of Rooms: 5.0
# Price: 500000.0, Number of Rooms: 5.0
# Least Expensive Apartments:
# Price: 670000.0, Number of Rooms: 5.0
# Price: 500000.0, Number of Rooms: 5.0
#
#
# Region: Kilsyth (AUDs)
# Most Expensive Apartments:
# Price: 811000.0, Number of Rooms: 4.0
# Price: 803000.0, Number of Rooms: 4.0
# Price: 780000.0, Number of Rooms: 4.0
# Price: 710000.0, Number of Rooms: 4.0
# Least Expensive Apartments:
# Price: 811000.0, Number of Rooms: 4.0
# Price: 803000.0, Number of Rooms: 4.0
# Price: 780000.0, Number of Rooms: 4.0
# Price: 710000.0, Number of Rooms: 4.0
#
#
# Region: Montrose (AUDs)
# Most Expensive Apartments:
# Price: 735000.0, Number of Rooms: 5.0
# Least Expensive Apartments:
# Price: 735000.0, Number of Rooms: 5.0
#
#
# Region: Aspendale Gardens (AUDs)
# Most Expensive Apartments:
# Price: 951000.0, Number of Rooms: 4.0
# Price: 880000.0, Number of Rooms: 4.0
# Price: 870000.0, Number of Rooms: 4.0
# Price: 840000.0, Number of Rooms: 5.0
# Least Expensive Apartments:
# Price: 951000.0, Number of Rooms: 4.0
# Price: 880000.0, Number of Rooms: 4.0
# Price: 870000.0, Number of Rooms: 4.0
# Price: 840000.0, Number of Rooms: 5.0
#
#
# Region: Bullengarook (AUDs)
# Most Expensive Apartments:
# Price: 535000.0, Number of Rooms: 4.0
# Least Expensive Apartments:
# Price: 535000.0, Number of Rooms: 4.0
#
#
# Region: Clarinda (AUDs)
# Most Expensive Apartments:
# Price: 1241000.0, Number of Rooms: 5.0
# Price: 976000.0, Number of Rooms: 6.0
# Price: 883300.0, Number of Rooms: 6.0
# Price: 790000.0, Number of Rooms: 4.0
# Least Expensive Apartments:
# Price: 1241000.0, Number of Rooms: 5.0
# Price: 976000.0, Number of Rooms: 6.0
# Price: 883300.0, Number of Rooms: 6.0
# Price: 790000.0, Number of Rooms: 4.0
#
#
# Region: Deepdene (AUDs)
# Most Expensive Apartments:
# Price: 1680000.0, Number of Rooms: 5.0
# Price: 710000.0, Number of Rooms: 3.0
# Least Expensive Apartments:
# Price: 1680000.0, Number of Rooms: 5.0
# Price: 710000.0, Number of Rooms: 3.0
#
#
# Region: Delahey (AUDs)
# Most Expensive Apartments:
# Price: 607500.0, Number of Rooms: 4.0
# Price: 563000.0, Number of Rooms: 4.0
# Price: 560000.0, Number of Rooms: 4.0
# Price: 550000.0, Number of Rooms: 4.0
# Price: 505000.0, Number of Rooms: 5.0
# Least Expensive Apartments:
# Price: 563000.0, Number of Rooms: 4.0
# Price: 560000.0, Number of Rooms: 4.0
# Price: 550000.0, Number of Rooms: 4.0
# Price: 505000.0, Number of Rooms: 5.0
# Price: 475000.0, Number of Rooms: 4.0
#
#
# Region: Hurstbridge (AUDs)
# Most Expensive Apartments:
# Price: 790000.0, Number of Rooms: 6.0
# Price: 600000.0, Number of Rooms: 4.0
# Least Expensive Apartments:
# Price: 790000.0, Number of Rooms: 6.0
# Price: 600000.0, Number of Rooms: 4.0
#
#
# Region: Kurunjang (AUDs)
# Most Expensive Apartments:
# Price: 375000.0, Number of Rooms: 4.0
# Price: 362000.0, Number of Rooms: 5.0
# Price: 345000.0, Number of Rooms: 5.0
# Price: 330000.0, Number of Rooms: 4.0
# Least Expensive Apartments:
# Price: 375000.0, Number of Rooms: 4.0
# Price: 362000.0, Number of Rooms: 5.0
# Price: 345000.0, Number of Rooms: 5.0
# Price: 330000.0, Number of Rooms: 4.0
#
#
# Region: Wonga Park (AUDs)
# Most Expensive Apartments:
# Price: 900000.0, Number of Rooms: 4.0
# Least Expensive Apartments:
# Price: 900000.0, Number of Rooms: 4.0
#
#
# Region: Endeavour Hills (AUDs)
# Most Expensive Apartments:
# Price: 1015000.0, Number of Rooms: 6.0
# Price: 676000.0, Number of Rooms: 4.0
# Price: 630000.0, Number of Rooms: 4.0
# Price: 625000.0, Number of Rooms: 5.0
# Price: 580000.0, Number of Rooms: 4.0
# Least Expensive Apartments:
# Price: 1015000.0, Number of Rooms: 6.0
# Price: 676000.0, Number of Rooms: 4.0
# Price: 630000.0, Number of Rooms: 4.0
# Price: 625000.0, Number of Rooms: 5.0
# Price: 580000.0, Number of Rooms: 4.0
#
#
# Region: Officer (AUDs)
# Most Expensive Apartments:
# Price: 559000.0, Number of Rooms: 5.0
# Least Expensive Apartments:
# Price: 559000.0, Number of Rooms: 5.0
#
#
# Region: Waterways (AUDs)
# Most Expensive Apartments:
# Price: 1265000.0, Number of Rooms: 5.0
# Price: 1232000.0, Number of Rooms: 5.0
# Least Expensive Apartments:
# Price: 1265000.0, Number of Rooms: 5.0
# Price: 1232000.0, Number of Rooms: 5.0
#
#
# Region: Ardeer (AUDs)
# Most Expensive Apartments:
# Price: 730000.0, Number of Rooms: 4.0
# Price: 645000.0, Number of Rooms: 4.0
# Price: 627000.0, Number of Rooms: 4.0
# Least Expensive Apartments:
# Price: 730000.0, Number of Rooms: 4.0
# Price: 645000.0, Number of Rooms: 4.0
# Price: 627000.0, Number of Rooms: 4.0
#
#
# Region: Beaconsfield (AUDs)
# Most Expensive Apartments:
# Price: 670000.0, Number of Rooms: 5.0
# Price: 537000.0, Number of Rooms: 4.0
# Least Expensive Apartments:
# Price: 670000.0, Number of Rooms: 5.0
# Price: 537000.0, Number of Rooms: 4.0
#
#
# Region: Springvale South (AUDs)
# Most Expensive Apartments:
# Price: 850000.0, Number of Rooms: 5.0
# Price: 750000.0, Number of Rooms: 4.0
# Price: 700000.0, Number of Rooms: 4.0
# Least Expensive Apartments:
# Price: 850000.0, Number of Rooms: 5.0
# Price: 750000.0, Number of Rooms: 4.0
# Price: 700000.0, Number of Rooms: 4.0
#
#
# Region: Yarra Glen (AUDs)
# Most Expensive Apartments:
# Price: 620000.0, Number of Rooms: 4.0
# Least Expensive Apartments:
# Price: 620000.0, Number of Rooms: 4.0
#
#
# Region: Brookfield (AUDs)
# Most Expensive Apartments:
# Price: 456000.0, Number of Rooms: 5.0
# Least Expensive Apartments:
# Price: 456000.0, Number of Rooms: 5.0
#
#
# Region: Emerald (AUDs)
# Most Expensive Apartments:
# Price: 655000.0, Number of Rooms: 3.0
# Least Expensive Apartments:
# Price: 655000.0, Number of Rooms: 3.0
#
#
# Region: Whittlesea (AUDs)
# Most Expensive Apartments:
# Price: 601000.0, Number of Rooms: 4.0
# Least Expensive Apartments:
# Price: 601000.0, Number of Rooms: 4.0
#
#
# Region: Burnside (AUDs)
# Most Expensive Apartments:
# Price: 657500.0, Number of Rooms: 4.0
# Price: 580000.0, Number of Rooms: 4.0
# Least Expensive Apartments:
# Price: 657500.0, Number of Rooms: 4.0
# Price: 580000.0, Number of Rooms: 4.0
#
#
# Region: Attwood (AUDs)
# Most Expensive Apartments:
# Price: 640000.0, Number of Rooms: 4.0
# Least Expensive Apartments:
# Price: 640000.0, Number of Rooms: 4.0
#
#
# Region: Wallan (AUDs)
# Most Expensive Apartments:
# Price: 366000.0, Number of Rooms: 4.0
# Least Expensive Apartments:
# Price: 366000.0, Number of Rooms: 4.0
#
#
# Region: New Gisborne (AUDs)
# Most Expensive Apartments:
# Price: 1355000.0, Number of Rooms: 6.0
# Least Expensive Apartments:
# Price: 1355000.0, Number of Rooms: 6.0
#
#
# Region: Plumpton (AUDs)
# Most Expensive Apartments:
# Price: 625500.0, Number of Rooms: 5.0
# Least Expensive Apartments:
# Price: 625500.0, Number of Rooms: 5.0
#
#
# Region: Monbulk (AUDs)
# Most Expensive Apartments:
# Price: 720000.0, Number of Rooms: 5.0
# Least Expensive Apartments:
# Price: 720000.0, Number of Rooms: 5.0

# %% [markdown]
# Next, we will be looking at the analysis of the Utrecht Housing Data Set, creating a python dictionary (c++ map equivalent) from this dataset.

# %%
# import pandas
import pandas as pd
# Read CSV
utr_df = pd.read_csv('utrechthousinghuge.csv')
utr_data = utr_df[['retailvalue', 'bathrooms']]
# Convert the Data from the CSV to a Dictionary
utr_dict = {}
for index, row in utr_data.iterrows():
  # General Entry into the Dictionary
  suburb = "Utrecht" # Setting every region to Utrecht because no regional specifics were provided
  price = row['retailvalue']
  num_rooms = row['bathrooms']

  # Seeing if a suburb (key) is already in the dictionary or not, appending if is, making new key if not)
  if suburb not in utr_dict:
    utr_dict[suburb] = []
  utr_dict[suburb].append((price, num_rooms))

# Sorting the dictionary by price and printing the top 5 most and least expensive apartments
for region in utr_dict:
  utr_sorted = sorted(utr_dict[region], key=lambda x: x[0], reverse=True)
  most_expensive = utr_sorted[:5]
  least_expensive = utr_sorted[-5:]

  # Printing sorted list
  print(f"Region: {region} (euros)")
  print("Most Expensive Apartments:")
  for apt in most_expensive:
    print(f"Price: {apt[0]}, Number of Rooms: {apt[1]*2.0 + 1.0}")
  print("Least Expensive Apartments:")
  for apart in least_expensive:
    print(f"Price: {apart[0]}, Number of Rooms: {apart[1]+1.0}")
  print("\n")
# Out:
# Region: Utrecht (euros)
# Most Expensive Apartments:
# Price: 1428000, Number of Rooms: 3.0
# Price: 1389000, Number of Rooms: 3.0
# Price: 1383000, Number of Rooms: 3.0
# Price: 1374000, Number of Rooms: 5.0
# Price: 1372000, Number of Rooms: 5.0
# Least Expensive Apartments:
# Price: 430000, Number of Rooms: 2.0
# Price: 426000, Number of Rooms: 2.0
# Price: 424000, Number of Rooms: 2.0
# Price: 422000, Number of Rooms: 2.0
# Price: 419000, Number of Rooms: 2.0

# %% [markdown]
# Now we will look at the food prices throughout the world with the world food prices database.

# %%
# import pandas
import pandas as pd
# Read CSV
food_df = pd.read_csv('wfp_food_prices_database.csv')
food_data = food_df[['adm0_name', 'mp_price']]
# Convert the Data from the CSV to a Dictionary
# Calculate the average price of food in a place
average_prices = food_data.groupby('adm0_name')['mp_price'].mean()
food_dict = {}
food_dict = average_prices.to_dict()
# Sort the dictionary by average prices and find the top 5 and bottom 5
sorted_prices = sorted(food_dict.items(), key=lambda x: x[1])
top_5 = sorted_prices[-5:]
bottom_5 = sorted_prices[:5]
# Printing the results
print("Top 5 countries with highest average food prices (not accounting for currency exchange):")
for country, price in reversed(top_5):
    print(f"{country}: {price:.2f}")
print("\nBottom 5 countries with lowest average food prices:")
for country, price in bottom_5:
    print(f"{country}: {price:.2f}")
# Out:
# /var/folders/6_/v_srh0ln2zjdd0qj3vlntxdw0000gn/T/ipykernel_49496/3833842204.py:4: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   food_df = pd.read_csv('wfp_food_prices_database.csv')
# Top 5 countries with highest average food prices (not accounting for currency exchange):
# Somalia: 136534.46
# United Republic of Tanzania: 102524.25
# Colombia: 78511.15
# Iran  (Islamic Republic of): 64883.91
# Afghanistan: 35021.93
#
# Bottom 5 countries with lowest average food prices:
# Azerbaijan: 0.53
# Italy: 0.67
# Belarus: 0.96
# Zimbabwe: 1.01
# Timor-Leste: 1.49

# %% [markdown]
# Finally, we will look at overall living index with the cost of living index database, which will give an overall comparison among all the countries and overall cost index, consisting of all expenses

# %%
# import pandas
import pandas as pd
# Read CSV
global_df = pd.read_csv('Cost_of_Living_Index_2022.csv')
global_data = global_df[['Unnamed: 1', 'Unnamed: 2']]
# Convert the Data from the CSV to a Dictionary
global_dict = {}
for index, row in global_data.iterrows():
  # General Entry into the Dictionary
  country = row['Unnamed: 1']
  cli = row['Unnamed: 2']
  global_dict[country] = cli

# Sorting the dictionary by price and printing the top 5 most and least expensive apartments
for region in global_dict:
  global_sort = sorted(global_dict.items(), key=lambda x: x[1], reverse=True)
  most_expensive = global_sort[:5]
  least_expensive = global_sort[-5:]

# Printing sorted list
print("Most Expensive Countries:")
for apt in most_expensive:
  print(f"Cost of Living Index: {apt[0]}")
print("Least Expensive Countries:")
for apart in least_expensive:
  print(f"Cost of Living Index: {apart[0]}")
print("\n")
# Out:
# Most Expensive Countries:
# Cost of Living Index: Country
# Cost of Living Index: Iceland
# Cost of Living Index: Barbados
# Cost of Living Index: Jersey
# Cost of Living Index: Israel
# Least Expensive Countries:
# Cost of Living Index: Afghanistan
# Cost of Living Index: Pakistan
# Cost of Living Index: Bermuda
# Cost of Living Index: Switzerland
# Cost of Living Index: Norway
